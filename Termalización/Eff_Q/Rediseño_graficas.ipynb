# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks")
fig, ax1 = plt.subplots(figsize = (10,8))

plt.title(r"Yb$^{+}$ - Dy (T$_{a}$ = 0.0001 K, a = -8 $\times$ 10$^{-6}$)", fontsize = 20)
ax1.errorbar(q, means, yerr = stds, c = "k", fmt = "o" )
#ax1.plot(q, means, "grey", lw = 3, alpha = 0.5 )
#ax1.legend([r'm${1}$',r'm${2}$', r'm$_{3}$'], fontsize = 20, loc = 'lower left')
ax1.set_xlabel('q', fontsize = 20)
ax1.set_ylabel(r'$\langle$ E$_{K}$ $\rangle$ (K)', fontsize = 20)
ax1.set_ylim(1E-3,3E-2)
plt.xticks( fontsize = 15)
plt.yticks( fontsize = 15)
plt.tick_params(axis='x', size = 10)
plt.tick_params(axis='y', size = 10)
ax1.set_yscale("log")


left, bottom, width, height = [0.32, 0.49, 0.34, 0.34]
ax2 = fig.add_axes([left, bottom, width, height])
ax2.errorbar(q, means, yerr = stds, c = "k", fmt = "o")
ax2.set_yscale("log")
ax2.set_ylim(1E-3,4E-3)
ax2.set_xlim(0.05, 0.22)
ax2.set_xlabel('q', fontsize = 15)
ax2.set_ylabel(r'$\langle$ E$_{K}$ $\rangle$ (K)', fontsize = 15)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.tick_params(axis='x', size = 6)
plt.tick_params(axis='y', size = 6)
plt.savefig(fname = "q_minimum_Dy_aE_06.jpg", dpi = 300)

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('/home/quantic_user/Desktop/Ana/Termalización/Eff_Q/LiYb.csv', header=None, names=['Columna1', 'Columna2'])
x = df['Columna1']
y = df['Columna2']

#kevin estuvo acá Esteban también juja

plt.figure(figsize=(10, 10))
plt.plot(x, y, color='blue')
plt.title('Li-Yb', fontsize=24)  # Title with reference label and larger font size
plt.ylabel('Ion temperature (μK)', fontsize=26)
plt.xlabel('Q', fontsize=26)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
#plt.text(490, valor_promedio - 0.02, f'{valor_promedio:.2f}', color='black', ha='right')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('/home/quantic_user/Desktop/Ana/Termalización/Eff_Q/Dy-Yb.csv', header=None, names=['Columna1', 'Columna2'])
x = df['Columna1']
y = df['Columna2']

#kevin estuvo acá Esteban también juja

plt.figure(figsize=(10, 10))
plt.plot(x, y, color='blue')
plt.title('Dy_Yb', fontsize=24)  # Title with reference label and larger font size
plt.ylabel('', fontsize=26)
plt.xlabel('Q', fontsize=26)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
#plt.text(490, valor_promedio - 0.02, f'{valor_promedio:.2f}', color='black', ha='right')
plt.show()
