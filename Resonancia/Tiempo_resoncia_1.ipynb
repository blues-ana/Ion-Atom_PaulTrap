# %%
#Calculo del tiempo de resonancia
import numpy as np
import math
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import random
from mpl_toolkits.mplot3d import Axes3D
from multiprocessing import Pool, cpu_count
import time
import logging

#Ion: Yb+ , atom: Li

#constants
m_ion = 2.8733965E-25  #(YB+) 2,8733965 × 10^-25 kg (SR+ 2.83E-25)
m_atom = 1.1525801E-26 # (LITIO) 1,1525801 × 10^-26 kg (RB 1.44E-25 )
C4=5.607E-57   #C4=5.607E-57   Paper Prospects #C4=1.1E-56 RbSr+
C6=5E-19 * C4   #C6=5.0E-19     Paper Prospects (LIYB+) C6 = 2.803 × 10−75 Jm6 C4 = 2.803 × 10−57
frf = 2.5 * 10**6
Omega= 2 * np.pi * frf #MHz #Depende tambien mucho de esta fase
a = -2.982E-4  #-3E-7, da un buen comportamiento
q = 0.1      #Entre 0.1 y otro
T_ion =  0 # da un buen comportamiento  0.5 milikelvin   Paper Ziv Meir (de Jesus)
T_atom = 0.1E-6  #0.1E-6, da un buen comportamiento   #6 microkelvin (mucho más frio átomo que ion) Paper Ziv Meir
r0 = 0.1E-6
ti= 0
tf= 10E-6          #0.001, da un buen comportamiento pal ion #de matlab 200e-6; SE PUEDE CAMBIAR A 200
dt= 1000
ptol = 1e-10
kB = 1.38064E-23
e = -1.6E-19
num_cpus = 24
num_solution = 1
num_collisions = 1000

logging.basicConfig(level=logging.INFO)

def system(t, y, a, q, Omega, C4, C6, m_ion, m_a):

    ionx, iony, ionz, ionvx, ionvy, ionvz, atomx, atomy, atomz, atomvx, atomvy, atomvz = y

    # Definición de las ecuaciones diferenciales
    dydt = np.zeros_like(y)

    #Velocidades del ion
    dydt[0] = ionvx
    dydt[1] = ionvy
    dydt[2] = ionvz

    #velocidades del átomo
    dydt[6] = atomvx
    dydt[7] = atomvy
    dydt[8] = atomvz

    #Potencial para el ion
    dydt[3] = -(a+2*q*np.cos(Omega*t)) *ionx*(Omega**2 / 4)
    dydt[4] = -(a+2*q*np.cos(Omega*t)) *iony*(Omega**2 / 4)
    dydt[5] = -(2*a+2*-q*np.cos(Omega*t)) *ionz*(Omega**2 / 4)

    #Interacción con el potencial atom
    r = np.sqrt((atomx - ionx)**2 + (atomy - iony)**2 + (atomz - ionz)**2)

    dydt[3] += -(2*C4/r**5 -6 *C6 / r**7) * (ionx - atomx) / (m_ion * r)
    dydt[4] += -(2*C4/r**5 -6 *C6 / r**7) * (iony - atomy) / (m_ion * r)
    dydt[5] += -(2*C4/r**5 -6 *C6 / r**7) * (ionz - atomz) / (m_ion * r)

    dydt[9] += -(2*C4/r**5 -6 *C6 / r**7) * (atomx - ionx) / (m_atom * r)
    dydt[10] += -(2*C4/r**5 -6 *C6 / r**7) * (atomy - iony) / (m_atom * r)
    dydt[11] += -(2*C4/r**5 -6 *C6 / r**7) * (atomz - ionz) / (m_atom * r)

    return dydt

#Funciones
def position_on_sphere(radius):
    phi = 2 * np.pi * np.random.rand()
    theta = np.arccos(2 * np.random.rand() - 1)
    # Convertir a coordenadas cartesianas
    x = radius * np.sin(theta) * np.cos(phi)
    y = radius * np.sin(theta) * np.sin(phi)
    z = radius * np.cos(theta)
    return x, y, z

def velocidad_atom(temperature, mass, x, y, z):
    phi = 2 * np.pi * np.random.rand()
    theta = np.arccos(2 * np.random.rand() - 1)

    kb = 1.380649e-23  # Constante de Boltzmann en m^2 kg s^-2 K^-1

    # Spherical velocities
    v_theta = np.sqrt((2 * kb * temperature) / mass) * random.gauss(0, 1)
    v_phi = np.sqrt((2 * kb * temperature) / mass) * random.gauss(0, 1)
    v_r = -abs(np.random.weibull(2) * np.sqrt(2 * kb * temperature / mass))

    # Componentes de velocidad en coordenadas cartesianas
    v_x = v_r * np.sin(theta) * np.cos(phi) + v_theta * np.cos(theta) * np.cos(phi) - v_phi * np.sin(phi)
    v_y = v_r * np.sin(theta) * np.sin(phi) + v_theta * np.cos(theta) * np.sin(phi) + v_phi * np.cos(phi)
    v_z = v_r * np.cos(theta) - v_theta * np.sin(theta)

    return v_x, v_y, v_z

def velocidad_ion(temperature, mass):
    kb = 1.38064E-23  # Constante de Boltzmann en m^2 g s^-2 K^-1, kelvin, metros, segundos, kilogramos
    v = np.sqrt((2 * kb * temperature) / mass) * random.gauss(0, 1)
    return v

# Definición del vector de tiempo
t_span = (ti, tf)

# Resolución del sistema de ecuaciones diferenciales
def run_simulation(i):

    ionx_0=0.0
    iony_0=0.0
    ionz_0=0.0
    ionvx_0=velocidad_ion(T_ion, m_ion)
    ionvy_0=velocidad_ion(T_ion, m_ion)
    ionvz_0=velocidad_ion(T_ion, m_ion)
    atomx_0, atomy_0, atomz_0 = position_on_sphere(r0)
    atomvx_0, atomvy_0, atomvz_0 = velocidad_atom(T_atom, m_atom, atomx_0, atomy_0, atomz_0)
    y0 = [ionx_0, iony_0, ionz_0, ionvx_0, ionvy_0, ionvz_0, atomx_0, atomy_0, atomz_0, atomvx_0, atomvy_0, atomvz_0]
    

    results = []

    for collision in range (num_collisions):
          #inicialization variables
        solution = solve_ivp(system, t_span, y0, t_eval=np.linspace(t_span[0], t_span[1], dt), method='RK45', args=(a, q, Omega, C4, C6, m_ion, m_atom), rtol=ptol)

        # Extracción de las soluciones temporales
        t_sol = solution.t
        ionx_sol = solution.y[0]
        iony_sol = solution.y[1]
        ionz_sol = solution.y[2]
        ionvx_sol = solution.y[3]
        ionvy_sol = solution.y[4]
        ionvz_sol = solution.y[5]
        atomx_sol = solution.y[6]
        atomy_sol = solution.y[7]
        atomz_sol = solution.y[8]
        atomvx_sol = solution.y[9]
        atomvy_sol = solution.y[10]
        atomvz_sol = solution.y[11]

        results.append([t_sol, ionx_sol, iony_sol, ionz_sol, ionvx_sol, ionvy_sol, ionvz_sol, atomx_sol, atomy_sol, atomz_sol, atomvx_sol, atomvy_sol, atomvz_sol])

        #Se reinian las condiciones para el atomo
        atomx_0, atomy_0, atomz_0 = position_on_sphere(r0)
        atomvx_0, atomvy_0, atomvz_0 = velocidad_atom(T_atom, m_atom, atomx_0, atomy_0, atomz_0)
        #Para este caso se reinicia condiciones para el ion
        y0 = [ionx_0, iony_0, ionz_0, ionvx_0, ionvy_0, ionvz_0, atomx_0, atomy_0, atomz_0, atomvx_0, atomvy_0, atomvz_0]
        #y0 = [ionx_sol[-1], iony_sol[-1], ionz_sol[-1], ionvx_sol[-1], ionvy_sol[-1], ionvz_sol[-1], atomx_0, atomy_0, atomz_0, atomvx_0, atomvy_0, atomvz_0]

    return results

if __name__ == '__main__':

    logging.info("Inicio de la ejecución")
    start_time = time.time()
    with Pool(processes=num_cpus) as pool:
        all_results = pool.map(run_simulation, range(num_solution))
    
    end_time = time.time()
    execution_time = (end_time - start_time)/60
    logging.info("Ejecución completada")
    print(f"Tiempo total de ejecución con 24 nucleos: {execution_time:.2f}minutos")
# Out:
# INFO:root:Inicio de la ejecución
# INFO:root:Ejecución completada
# Tiempo total de ejecución con 24 nucleos: 7.79minutos

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define el radio de la esfera
r0 = 0.1E-6

# Bucle para iterar sobre todas las colisiones y trayectorias
for i, results in enumerate(all_results):   # cada colisión en el número de trayectorias
    for j, result in enumerate(results):    # parámetros de cada colisión
        t_sol = result[0]
        ionx_sol = result[1]
        iony_sol = result[2]
        ionz_sol = result[3]
        ionvx_sol = result[4]
        ionvy_sol = result[5]
        ionvz_sol = result[6]
        atomx_sol = result[7]
        atomy_sol = result[8]
        atomz_sol = result[9]
        atomvx_sol = result[10]
        atomvy_sol = result[11]
        atomvz_sol = result[12]

        # Cálculo de la distancia entre el átomo y el origen (0, 0, 0)
        salida_times = []  # Lista para almacenar los tiempos de salida del átomo de la esfera
        for k in range(1, len(t_sol)):
            r_anterior = np.sqrt(atomx_sol[k-1]**2 + atomy_sol[k-1]**2 + atomz_sol[k-1]**2)
            r_actual = np.sqrt(atomx_sol[k]**2 + atomy_sol[k]**2 + atomz_sol[k]**2)
            
            if r_anterior < r0 and r_actual >= r0:
                # Interpolación lineal para obtener el tiempo más preciso de cruce
                t_salida = t_sol[k-1] + (r0 - r_anterior) / (r_actual - r_anterior) * (t_sol[k] - t_sol[k-1])
                salida_times.append(t_salida)
                #print(f'El átomo sale de la esfera en t = {t_salida:.10e} s con interpolación')
                break

salida_time_promedio = np.mean(salida_times)

print(f'El átomo sale de la esfera en t (promedio) = {t_salida:.10e} s con interpolación')
# Out:
# El átomo sale de la esfera en t (promedio) = 1.4006152114e-06 s con interpolación

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define el radio de la esfera
r0 = 0.1E-6

# Bucle para iterar sobre todas las colisiones y trayectorias
for i, results in enumerate(all_results):   # cada colisión en el número de trayectorias
    for j, result in enumerate(results):    # parámetros de cada colisión
        t_sol = result[0]
        ionx_sol = result[1]
        iony_sol = result[2]
        ionz_sol = result[3]
        ionvx_sol = result[4]
        ionvy_sol = result[5]
        ionvz_sol = result[6]
        atomx_sol = result[7]
        atomy_sol = result[8]
        atomz_sol = result[9]
        atomvx_sol = result[10]
        atomvy_sol = result[11]
        atomvz_sol = result[12]

        # Graficar las trayectorias del ion y del átomo
        plt.plot(ionx_sol, iony_sol, label='Ion')
        plt.plot(atomx_sol, atomy_sol, label='Átomo')

        # Imprimir las condiciones iniciales y finales del ion y del átomo
        print('Iniciales_ion:', ionx_sol[0], iony_sol[0], ionvx_sol[0], ionvy_sol[0])
        print('Finales_ion:', ionx_sol[-1], iony_sol[-1], ionvx_sol[-1], ionvy_sol[-1])
        print('Iniciales_atom:', atomx_sol[0], atomy_sol[0], atomvx_sol[0], atomvy_sol[0])
        print('Finales_atom:', atomx_sol[-1], atomy_sol[-1], atomvx_sol[-1], atomvy_sol[-1])

        # Graficar la esfera de radio r0 alrededor de (0,0)
        circle = plt.Circle((0, 0), r0, color='r', fill=False, linestyle='--', label=f'Esfera de radio {r0:.1E} m')
        plt.gca().add_artist(circle)

        # Cálculo de la distancia entre el átomo y el origen (0, 0, 0)
        salida_times = []  # Lista para almacenar los tiempos de salida del átomo de la esfera
        for k in range(1, len(t_sol)):
            r_anterior = np.sqrt(atomx_sol[k-1]**2 + atomy_sol[k-1]**2 + atomz_sol[k-1]**2)
            r_actual = np.sqrt(atomx_sol[k]**2 + atomy_sol[k]**2 + atomz_sol[k]**2)
            
            if r_anterior < r0 and r_actual >= r0:
                # Interpolación lineal para obtener el tiempo más preciso de cruce
                t_salida = t_sol[k-1] + (r0 - r_anterior) / (r_actual - r_anterior) * (t_sol[k] - t_sol[k-1])
                salida_times.append(t_salida)
                print(f'El átomo sale de la esfera en t = {t_salida:.10e} s con interpolación')
                break

        # Configuración de límites y etiquetas del gráfico
        plt.xlim(-1E-7, 1E-7)
        plt.ylim(-1E-6, 1E-6)
        plt.xlabel('X (m)')
        plt.ylabel('Y (m)')
        plt.legend()
        plt.title('Trayectorias del Ion y del Átomo')

        # Mostrar la gráfica
        #plt.show()
salida_time_promedio = np.mean(salida_times)
print(salida_time_promedio)
# Out:
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.9924683945169764e-09 -1.7611173063367434e-09 0.0006827047756313856 0.0008231107048281817
# Iniciales_atom: 5.42509763325375e-08 5.153697459024658e-08 -0.009014933225610202 -0.01207180200753409
# Finales_atom: -1.9509219570193809e-07 -2.1297065997525535e-07 -0.01861217892346488 -0.019397884861440087
# El átomo sale de la esfera en t = 1.4662529156e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.2940683382176714e-09 -8.649559863311388e-10 0.0003636806943091792 -7.702244188815817e-05
# Iniciales_atom: 1.1919880772547452e-09 1.7805284508488193e-08 -0.013206884232559842 -0.009224165866163883
# Finales_atom: -8.576536953980159e-08 -8.078573013324746e-08 0.0045320294421962596 0.001775968869262817
# El átomo sale de la esfera en t = 1.3695878185e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.8611645006632635e-09 -6.163808428056466e-10 -0.0008144791465662217 -0.00036588290713328916
# Iniciales_atom: 3.506878029467848e-08 1.7028116409427999e-09 -0.004910526633665935 -0.004562689878501802
# Finales_atom: -4.135744223414622e-07 -1.1192643338231069e-07 -0.053039473280671594 -0.013954785212113324
# El átomo sale de la esfera en t = 2.1292671064e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.828050057060065e-10 2.9952003597422986e-09 0.0018903197197873414 0.0006064987805913548
# Iniciales_atom: 3.626055391735379e-08 7.967675228195258e-08 -0.005805073087361266 0.0004575612494938548
# Finales_atom: -5.419958773940188e-08 -1.0660380576396644e-08 -0.06300531072863404 -0.023941732661535365
# El átomo sale de la esfera en t = 1.4834049469e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.1588793496394035e-09 1.1566849211850098e-09 8.378051974881071e-05 3.9021173590969376e-05
# Iniciales_atom: 2.7996634678395368e-09 -8.926896808333772e-09 0.015839899296285556 0.009711287090841552
# Finales_atom: 1.151252151200496e-07 7.291860733590556e-08 -0.00806201008665941 -0.0036393805593833584
# El átomo sale de la esfera en t = 2.9887885790e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 4.686912916343313e-10 4.124326495466152e-10 0.0010520945229009183 0.0012982896853204608
# Iniciales_atom: 1.4757436491149015e-08 2.467506159194085e-08 -0.008072837644351098 -0.007922782682100329
# Finales_atom: -6.204268400987104e-08 -8.318564227173095e-08 -0.0090237841226345 -0.01335535584468891
# El átomo sale de la esfera en t = 3.1455058947e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -5.5412341128420294e-09 1.995422629591236e-09 -0.001709977611162847 0.000604708951967072
# Iniciales_atom: -7.076777722748671e-08 -4.0307926021002317e-08 0.05169980240889932 0.005433552839652918
# Finales_atom: 1.9089584855577775e-07 1.9378633564124985e-07 0.02194960221321848 0.03117710913066365
# El átomo sale de la esfera en t = 1.2148121857e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 7.508696434238002e-10 1.0723084802388515e-09 -0.0004639157459256014 -0.00042795249989629645
# Iniciales_atom: 3.816370971589958e-08 9.205352197111272e-08 0.0027477963912980984 0.0016446482479793231
# Finales_atom: -4.669700974446621e-08 -1.1241033300711639e-07 -0.004441452493078925 -0.006526354904992633
# El átomo sale de la esfera en t = 3.1165092267e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -6.727367203796995e-10 -1.0469297260790604e-09 0.0011374019860158615 -0.0006529198318921904
# Iniciales_atom: -2.3513278459801687e-08 -9.622445358182246e-08 -0.0021131743143427617 0.001105778756839208
# Finales_atom: -1.051413387163964e-08 3.808109466329962e-08 -0.004871127558712111 0.0433220191738239
# El átomo sale de la esfera en t = 1.5863253923e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 7.973684822311137e-10 2.3604834341061426e-09 0.0026761933276483866 -0.00189028172278674
# Iniciales_atom: -8.54152020460263e-09 9.962890102182174e-08 -0.019028701901734633 -0.014435042152153901
# Finales_atom: 4.4835976832872724e-08 -9.198075996546619e-08 0.007774069752995973 0.03342390006822026
# El átomo sale de la esfera en t = 1.2949832972e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.0010230712913516e-09 1.1265276273895826e-09 0.00046149341010722546 2.8015535910871854e-05
# Iniciales_atom: 6.23956165133792e-08 -1.9310521937256044e-08 -0.013075215871131095 -0.0019664090844323766
# Finales_atom: -1.8739179364064273e-07 2.0241278215139015e-08 -0.001113786987212921 0.002043230738275959
# El átomo sale de la esfera en t = 1.5159745533e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.2457335410383195e-10 7.246091968321155e-10 -0.0004451671320888365 -0.0008406657784846818
# Iniciales_atom: 6.48803502178651e-08 -1.6399665503157417e-08 -0.009030497474147888 0.011146764296226037
# Finales_atom: -1.1683854651407691e-07 1.31538419993474e-07 -0.008975704532541788 0.005275810803966458
# El átomo sale de la esfera en t = 1.3965201089e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.4887018532431628e-09 -3.6564885245999944e-11 -0.0006114959879139847 -0.0007698164166789661
# Iniciales_atom: 9.437555378492443e-08 -2.537882314000237e-08 -0.005115683753138449 -0.014402691442498828
# Finales_atom: -1.3708035971422476e-07 -9.308491416189526e-08 -0.012173077322139037 0.0023835776162260095
# El átomo sale de la esfera en t = 1.5182137041e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.296167107589533e-09 2.454338585817544e-09 -1.1968785089748642e-05 5.4328617026110516e-06
# Iniciales_atom: 4.598231052760876e-08 8.408367898148113e-08 -0.008329645942180098 -0.014886854435150386
# Finales_atom: 5.043444474973095e-08 9.625919805419098e-08 -0.017075412467365228 -0.032293828965816895
# El átomo sale de la esfera en t = 1.2067067041e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.002222071410253e-11 -1.0239249840710114e-10 -7.775377318720053e-05 2.072450898495222e-05
# Iniciales_atom: -3.856475713568636e-08 9.096857024692112e-09 -0.02156537759779387 0.004266404241616596
# Finales_atom: -1.5194906189569498e-07 2.586106892480932e-08 0.010742988106217986 -0.002038035704846133
# El átomo sale de la esfera en t = 1.8478076556e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.7957505906562e-10 1.2415163685888667e-09 0.00028212675843249167 0.0013777430741804297
# Iniciales_atom: -1.6249844255178727e-08 -9.554831375379181e-08 0.008328701021624722 0.0015105931180802584
# Finales_atom: 1.1317724538840628e-07 2.6555506602281885e-07 0.01429517908543134 0.0405466371911688
# El átomo sale de la esfera en t = 1.3438701810e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 6.838601025993288e-10 7.05578227033331e-10 -0.0004890306711841128 -0.0008914336353298376
# Iniciales_atom: 4.1980766007785095e-08 5.2832924140899196e-08 -0.006132585719946149 -0.01618066084235408
# Finales_atom: -5.0153637559070975e-08 -1.078147249417948e-07 -0.003890959535110494 -0.0014139289274524786
# El átomo sale de la esfera en t = 1.3813243193e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.7412590203089207e-10 5.624851595810032e-10 -0.0011487970705335003 0.0026347758740357316
# Iniciales_atom: -5.4142505877173306e-08 -6.375693971730518e-08 0.01601280226856058 -0.01564669812781479
# Finales_atom: 1.3649126583733966e-08 9.654369347686707e-08 -0.022606076389191102 -0.025046745210438863
# El átomo sale de la esfera en t = 1.5280165167e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.4289434350585819e-09 -5.822230486234996e-10 9.483567119175054e-05 0.00022325632101423076
# Iniciales_atom: -2.5589972527160173e-08 7.353989269214751e-08 0.010636841352697223 -0.012383861926375176
# Finales_atom: 1.9638088911038095e-07 -2.1586543926723102e-07 0.021077430822004434 -0.025585018783682335
# El átomo sale de la esfera en t = 1.4319534317e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.5956306103572925e-10 -7.826689078162029e-10 -0.00034086606894215786 0.0006752037635235263
# Iniciales_atom: 6.026584747380313e-08 -4.155437183485532e-08 -0.009344812004517016 -0.0027834241175042265
# Finales_atom: 6.937829687296985e-08 -1.9342228901481335e-07 -0.0004164964655827365 -0.00682028179419847
# El átomo sale de la esfera en t = 1.2559898024e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -7.101841246673093e-09 2.417867556721801e-11 -0.0008683760164812705 -0.00193508883629999
# Iniciales_atom: 8.903448464460092e-08 -3.874479264161479e-08 0.009969682240686313 0.017821257816788335
# Finales_atom: -1.217153457089541e-07 1.515460965691017e-10 0.00439386528350676 -0.013406613001139517
# El átomo sale de la esfera en t = 2.6000548082e-21 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -4.320588764365577e-09 -5.339480965574186e-09 -0.0026895102894984916 -5.262723597884104e-06
# Iniciales_atom: -3.3477887128817006e-08 9.365381281798887e-08 0.02385348330241717 0.01450035548665991
# Finales_atom: -7.04480809331939e-09 -2.275948686669686e-07 -0.011136958888640393 -0.02432459580618719
# El átomo sale de la esfera en t = 1.6246363906e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.4748488030822385e-09 -1.964765834006378e-09 -0.00040249634905013387 0.0006632254094055565
# Iniciales_atom: -4.573755571704341e-08 5.730905023732783e-08 -0.0035982767557716762 -0.002177778192380494
# Finales_atom: 1.9275985876411054e-07 -3.205110240539545e-07 0.02405945521370585 -0.0384423848944211
# El átomo sale de la esfera en t = 1.7666310731e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.9534021551735662e-10 5.143918844175836e-10 0.0006358417190616268 -1.0745424063392088e-05
# Iniciales_atom: 1.1751518935857441e-08 -3.234167904912851e-08 -0.024639915944803994 0.003925389567219153
# Finales_atom: -1.2106418203845424e-07 7.502743903651782e-08 -0.004278458278535706 0.008785368701682882
# El átomo sale de la esfera en t = 3.0556487920e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.888369764330609e-09 -2.2889888269867725e-09 -0.00028681628790878976 0.0004593154292412701
# Iniciales_atom: -3.5956388295721694e-08 6.20908787039763e-08 0.014675430166807404 -0.01877547268057399
# Finales_atom: 1.0812556257972846e-07 -1.5307351978069003e-07 -0.00244919483718932 0.0012354799760108592
# El átomo sale de la esfera en t = 1.4087823068e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -6.102282356744796e-12 -8.143841791873978e-10 -0.0009202528286397095 0.00021632712015878325
# Iniciales_atom: -9.493638448220941e-08 4.751466745785492e-09 -0.007027878449075123 -0.010015276976318453
# Finales_atom: 5.385475603860552e-08 -8.900012524265388e-08 0.02549795431598455 -0.02351743932836735
# El átomo sale de la esfera en t = 4.5483685719e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.2922490002467023e-10 1.2498801489145472e-10 0.00014161228192096086 -3.686851656513016e-05
# Iniciales_atom: 8.865570979248707e-08 -3.512852999143463e-08 0.02045482242065402 -0.008448750829037266
# Finales_atom: 1.457395960624516e-07 -6.180964193429058e-08 0.0003648595283869659 -0.00036296931634811067
# El átomo sale de la esfera en t = 1.5452807870e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.3204972041485743e-09 8.122120403058584e-10 0.0006309629985131875 -0.0012930100724956523
# Iniciales_atom: 2.7400363759789824e-09 -9.761665913105687e-08 -0.018142525108124738 -0.03493125610858411
# Finales_atom: -3.6211033376555674e-07 -2.5087497183131625e-07 -0.03481113945381486 -0.018881329580951744
# El átomo sale de la esfera en t = 1.9004388705e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.7216871807278454e-09 -1.1353425941727328e-11 -0.001355428137378109 -0.0002533384339803145
# Iniciales_atom: -6.820731864601777e-08 3.037229169286827e-08 0.026814821852916344 -0.017098452360576645
# Finales_atom: -3.4041383044633807e-07 -7.347782065219697e-09 -0.05070968288634681 -0.0021977363724722246
# El átomo sale de la esfera en t = 1.0820668228e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -8.826766170554405e-10 -1.2152874750268708e-09 -0.0028224920181419096 0.0020209206763131173
# Iniciales_atom: 2.418551676125037e-08 -7.325014382017467e-08 0.003922426092167372 0.01087874705722712
# Finales_atom: 1.2949375352584047e-07 -2.7944380942739876e-08 0.03408778777359806 -0.002103157939488659
# El átomo sale de la esfera en t = 1.2757845323e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.6132612353338121e-09 -8.059510820336473e-10 -0.0015804692699269585 0.0015595707054879729
# Iniciales_atom: 9.131236139217419e-08 3.513190476292047e-08 0.0407309500113203 0.008062604772830625
# Finales_atom: 1.1543377969347856e-07 -7.44208514718913e-08 0.03490893719088975 -0.02770657647400288
# El átomo sale de la esfera en t = 3.5205010084e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.540653552980597e-09 4.683731796471541e-09 0.0019799374008602423 -0.003942509673975638
# Iniciales_atom: 4.8307891495260713e-08 -8.609311610058606e-08 0.0015379365493858885 0.0009189916458946258
# Finales_atom: -4.929213051347862e-08 8.106387613744999e-08 -0.019486766849645128 0.02883268073158717
# El átomo sale de la esfera en t = 3.1079419632e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.7210639718974926e-09 2.304334194762713e-09 0.00025121696630809676 -0.0007790676603577846
# Iniciales_atom: -8.847609787156225e-08 4.5025679536343594e-08 -0.0030936548001454347 0.005558076562253241
# Finales_atom: -5.689702403277254e-08 1.270311138538594e-07 -0.009728227678196552 0.02858300504188377
# El átomo sale de la esfera en t = 2.9783591666e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.8704842917422567e-09 1.1017566710677e-09 -0.002336619990321716 0.0011170809053233175
# Iniciales_atom: -9.174088685778151e-08 -1.3732465572702472e-08 -0.015766983100015012 0.01183870762018227
# Finales_atom: -2.1970967308021503e-07 3.49485792447598e-07 -0.022892493402491644 0.04299677247157613
# El átomo sale de la esfera en t = 1.5483367536e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.901225905077401e-09 -3.250187699146065e-09 -0.00044546479074336815 4.131116855069774e-06
# Iniciales_atom: 1.2629128208252713e-08 9.719554496988133e-08 -0.011458347790916024 0.0026598987801939307
# Finales_atom: -7.056382454908645e-08 -8.368329247566156e-08 0.028972126540886278 0.017585840414214404
# El átomo sale de la esfera en t = 4.6036810358e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.30491152401698e-10 -2.06595332093658e-09 -0.001882443637158726 0.0009030706429231061
# Iniciales_atom: -1.3314059308989772e-08 5.636504322519512e-08 0.02526472338618154 -0.01023619010548046
# Finales_atom: -1.0978591934846144e-07 2.5968200557412155e-08 -0.04636712175945941 0.021884252427910332
# El átomo sale de la esfera en t = 1.4330905755e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.4010785672027214e-09 -7.349311868804281e-10 -0.001044399343662992 -0.00013638338454709004
# Iniciales_atom: 4.8774019674734005e-08 -4.1360709655398406e-08 0.01563466694179558 -0.006725959224662653
# Finales_atom: 1.1617649716597491e-07 8.035453789884403e-10 0.024622648849732878 0.0031465682823484283
# El átomo sale de la esfera en t = 1.7020019160e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.3785361542184026e-09 2.3863454449604244e-09 0.0004121691274037642 -0.00018656248695984694
# Iniciales_atom: -7.82267102924025e-08 4.54789478439704e-08 0.016079039399467327 -0.0017452241125944668
# Finales_atom: -3.5236884263641065e-08 1.3643884624417865e-07 0.0068263741246455106 -0.010070677868092263
# El átomo sale de la esfera en t = 1.2464568424e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.2394938592794587e-09 -3.997974708534463e-09 -0.0012826028037910796 -0.0014068846311311618
# Iniciales_atom: -6.020682849939442e-08 2.9189382034779623e-08 -0.024192702760809932 -0.01198922483507563
# Finales_atom: -1.613681501323753e-09 -8.05971953169269e-08 0.020836949772113998 0.04981221358315739
# El átomo sale de la esfera en t = 1.6408579999e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.2937243990457805e-10 5.020777058021005e-10 0.0006625737222580338 -0.0012462652761576788
# Iniciales_atom: 4.713325473790585e-08 1.2927528632821998e-08 -0.0010698554376719137 0.019137402478559492
# Finales_atom: -9.874475232296019e-08 -1.101956943754213e-07 -0.01841889535238048 -0.02987542770030908
# El átomo sale de la esfera en t = 1.3279997846e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -6.143244446055937e-10 2.0018969414402347e-10 0.001977345622290653 0.0014117747891151584
# Iniciales_atom: 6.02762266058522e-08 2.6110405506092158e-08 0.01606817791509283 0.012576050150521698
# Finales_atom: 2.611836919198632e-07 2.628236997362985e-07 0.02795086414394148 0.029542273679393622
# El átomo sale de la esfera en t = 1.6065068705e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -8.283153398690431e-10 8.055980491132934e-10 0.0002797652130469904 -0.0007910974199844284
# Iniciales_atom: 2.102951430138749e-08 7.920087605495888e-08 -0.014178365217189444 -0.008734205113310915
# Finales_atom: -1.3725883543370936e-07 1.421557356994237e-07 -0.005048530474933655 -0.001535884762138582
# El átomo sale de la esfera en t = 1.2376747471e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.2981564189627907e-10 2.8153429937114153e-09 0.0025434200128629804 -0.0005407601029361448
# Iniciales_atom: -4.450480737973249e-08 8.695071268486904e-08 -0.007545882706205676 -0.023291436255653348
# Finales_atom: 3.235672807290332e-08 -1.9382031273031738e-07 0.017194131525152128 -0.045276567511185306
# El átomo sale de la esfera en t = 1.2065305670e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.564195303528894e-09 -2.8282148503645116e-09 -0.0019161192005979824 -0.0015954659293142385
# Iniciales_atom: -1.8447681373718115e-08 -5.0955550455693004e-08 0.016798764783141504 0.01853825632996952
# Finales_atom: 1.5482480621083298e-07 2.2176040350380691e-07 0.03437862298805689 0.0530303229063551
# El átomo sale de la esfera en t = 1.5455306681e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 6.982880695391585e-10 3.571071106365873e-10 -0.0044746213179191335 0.0003155974105590721
# Iniciales_atom: -4.704842597139906e-08 2.4804664532307597e-08 0.02447489830271066 0.0019216659232232057
# Finales_atom: 1.2652041064643453e-07 -3.9873705530456003e-08 0.04242516265741091 -0.01924294743419
# El átomo sale de la esfera en t = 1.4330434592e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.683895073387664e-09 6.119848135966639e-09 0.000391662747455738 -0.000444590273161368
# Iniciales_atom: 1.7838434898705607e-08 -5.984883267177404e-08 -0.02896804351723649 -0.02414011891246352
# Finales_atom: -5.523571042923183e-08 2.173667704906064e-07 0.0021105965495592178 0.029065793387615578
# El átomo sale de la esfera en t = 1.6635436702e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 7.077000012897046e-10 4.494149363634888e-09 -0.00019865430122722539 -0.0002758108631015213
# Iniciales_atom: -1.2644114118636123e-08 -8.504938622984676e-08 -0.004861824017658724 0.0004261845197886273
# Finales_atom: -4.370147192677532e-09 2.5380086027960516e-07 0.001317473473390557 0.02330089023318175
# El átomo sale de la esfera en t = 1.6304498249e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 6.440156488682875e-09 4.08640414179712e-09 -0.000765602405154964 -0.0004933556167023836
# Iniciales_atom: -8.039593613644837e-08 -4.919338247233798e-08 -0.0381059111220608 -0.02501700396609832
# Finales_atom: 3.449123187156541e-08 -3.1536476027660463e-09 0.009811807822921821 0.0031019429329889724
# El átomo sale de la esfera en t = 3.3084795271e-22 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.3775331370135775e-09 -9.681806885605445e-10 -0.0009477491299184943 -0.0007111857020757268
# Iniciales_atom: 2.376654488207041e-08 -4.542809227269771e-08 0.011595076258430943 0.01831125783896839
# Finales_atom: 7.157902610521369e-08 2.769282758139161e-07 0.00646446701830588 0.03842705647347559
# El átomo sale de la esfera en t = 1.4050227795e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -5.181160641519275e-09 -1.6686093967518742e-09 0.0004258428132777716 0.0020258027330899864
# Iniciales_atom: 7.089525976944593e-08 6.489498383026531e-08 0.004224671833885233 -0.020973367660937912
# Finales_atom: -4.357256729989059e-08 3.6336990704645015e-08 -0.02108552310561524 0.052413356284503596
# El átomo sale de la esfera en t = 1.4308708302e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -4.277781946363379e-09 4.874672972292401e-10 0.0011181238597410329 -0.0021525034481222234
# Iniciales_atom: 9.929261938028507e-08 7.545500838207871e-09 0.009496649586397574 0.016165873600923676
# Finales_atom: -1.577722752010565e-07 9.76044443126262e-08 -0.047902510785230716 0.021279930654287058
# El átomo sale de la esfera en t = 1.5956003591e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 7.584922022082483e-09 1.8516308495478041e-09 -0.004020613014944658 -0.0007466244305463582
# Iniciales_atom: -9.60046826941466e-08 -2.363685010630243e-08 0.025695674771740947 0.0008798300950622273
# Finales_atom: 6.357092736172142e-08 1.8396706630799506e-08 0.15299200255883907 0.051802938809426935
# El átomo sale de la esfera en t = 1.1752934608e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.7550657027063744e-09 2.2846130284048815e-09 0.0005336423686756197 -0.0018422909981181056
# Iniciales_atom: -4.3373385207941044e-08 -6.67244031892037e-08 -0.02584512316363928 -0.003123744038025185
# Finales_atom: 7.284191831942923e-08 8.546277583495708e-08 0.032551859962825384 0.018523871393213914
# El átomo sale de la esfera en t = 1.5832514058e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.2578505471367388e-09 -2.0903854703737584e-09 -0.0010380313333715934 0.0008411283585844454
# Iniciales_atom: -7.273292416386213e-08 5.245015756403115e-08 0.020153648433442726 0.007175212632061272
# Finales_atom: 4.90248830796804e-08 -8.679154765075793e-08 0.022739626818978884 -0.07275096079656553
# El átomo sale de la esfera en t = 1.2187848267e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.1319318089634973e-09 1.4186843252707789e-09 -0.0002724360488639791 -0.0009312327536085894
# Iniciales_atom: 8.898695801233919e-08 -4.5204190028755644e-08 0.0037991967346450058 0.015291367394349034
# Finales_atom: -1.3595066144989166e-07 3.028412651011451e-08 -0.030113283286469904 -0.004129472110987514
# El átomo sale de la esfera en t = 1.5727823439e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.3707063361281702e-09 2.806806140829433e-09 -0.0005929605018193178 -0.00040984340836383484
# Iniciales_atom: -4.002047416705702e-08 -9.133299777162625e-08 -0.015017319142895858 -0.009790740815884444
# Finales_atom: -9.278004041246295e-08 6.823026087791496e-08 -0.0077672549541499365 0.016567381924215894
# El átomo sale de la esfera en t = 1.5297078919e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.7161017106836793e-09 -2.565494695155565e-09 -0.0011122104715218571 -9.644903483507859e-05
# Iniciales_atom: 5.0984623238532106e-08 8.601708142113484e-08 -0.024305602706406394 -0.008214644806531808
# Finales_atom: -2.956192448151082e-07 8.333630411408699e-08 -0.04248176168883672 0.006068199501233514
# El átomo sale de la esfera en t = 1.2252772379e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 5.027748325424927e-09 -3.8719302466293755e-09 -0.0017999345483487358 -0.0015324009131573954
# Iniciales_atom: -6.052960438292563e-08 -1.7975550711271566e-08 -0.03070550929692851 0.018944664538970573
# Finales_atom: 3.5051203092967996e-08 -8.880668811731344e-08 -0.014345460918299252 -0.0017007955854427214
# El átomo sale de la esfera en t = 3.5298026902e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.632662991045711e-09 2.5581172196745304e-09 0.0005353105410996636 -0.00021688175968986845
# Iniciales_atom: 3.973452284300706e-08 -2.4594955600846042e-08 0.0011094603217812011 -0.03083756051960669
# Finales_atom: -9.141701064113438e-08 5.645289289649809e-10 -0.005886569941030952 0.012925858090743836
# El átomo sale de la esfera en t = 1.5561632734e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.780935058489988e-09 5.069477776554374e-10 -0.002168893135741203 -0.0029156979756496766
# Iniciales_atom: -5.417292727574204e-08 -1.7986250810373216e-08 0.00016498068883287476 0.021673791226982892
# Finales_atom: 3.075976714583941e-08 -9.677751350114587e-08 -0.0008781207772436574 -0.02728903868103372
# El átomo sale de la esfera en t = 1.7783109450e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.256163421800076e-09 -2.811083086593371e-09 0.0005036806959307612 -0.0008603345972025665
# Iniciales_atom: -2.2069627779460456e-08 -3.8279236363820984e-08 0.011359541276839894 -0.010364606113911969
# Finales_atom: 1.394505603649413e-07 -1.3144188725068266e-07 0.002205365982860608 0.002772882577785945
# El átomo sale de la esfera en t = 1.3939797370e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 9.968507444131603e-10 -2.55649194842311e-09 -7.534450050409658e-05 0.0004981007840023506
# Iniciales_atom: 2.5588799813098542e-09 -6.147143331043103e-08 0.005694563618035902 -0.0025956455200865656
# Finales_atom: 1.052638236833534e-07 -1.413595013950271e-07 0.005453524819472708 -0.00413399397388879
# El átomo sale de la esfera en t = 1.3623785297e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.5018307983715957e-09 2.6442755661971395e-09 -0.0005184008215829818 -0.0007298958864720943
# Iniciales_atom: -4.647896271792782e-08 -3.5302300615741818e-09 -0.004126087292381968 -0.010124572332644726
# Finales_atom: 7.516666848634908e-10 -1.725552483257361e-07 0.0026743028487363277 -0.01642436797069089
# El átomo sale de la esfera en t = 1.5825590923e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -4.316061905101271e-09 -2.2056280267324832e-09 -0.00017552547384940063 -0.0002757603497996089
# Iniciales_atom: -3.148605382035383e-08 1.1574603191446222e-08 0.01344822555308309 0.00591180554317306
# Finales_atom: 2.509921775840519e-07 8.693556649563331e-08 0.04576387239372836 0.01440978633818542
# El átomo sale de la esfera en t = 1.4212299028e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.0792364138404688e-09 6.102671550223698e-10 0.001782726873727161 -0.0017246895679591734
# Iniciales_atom: -2.239813704815208e-08 -4.224556662509292e-08 -0.03423084523853857 -0.003345536904171007
# Finales_atom: 2.2481590025265243e-07 7.310652369191632e-08 0.06050855376202322 0.014092839512893033
# El átomo sale de la esfera en t = 1.6258204431e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -6.67499576737429e-11 -6.660020554673379e-10 -0.000405803169009162 0.0008600155783685629
# Iniciales_atom: 9.436973889327665e-09 -6.591848552433648e-08 -0.0042298257141478125 0.014249859355592838
# Finales_atom: -3.405233701653622e-08 1.2370918179340864e-08 0.009733764943026297 0.0004610817547260049
# El átomo sale de la esfera en t = 1.3166374920e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.2726318579638186e-09 7.485773809126517e-10 0.0010480766022053876 -5.4963751300775114e-05
# Iniciales_atom: 9.213517242042569e-08 -2.8495270216628992e-08 0.008377002871375168 0.0025097045664283267
# Finales_atom: 5.081509027075246e-08 7.13734558262788e-08 -0.0023473725091068087 0.006365127498633164
# El átomo sale de la esfera en t = 3.6876737106e-21 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -5.320907826719609e-09 2.978195820213545e-09 -0.0035934991032015202 0.00037149020593389226
# Iniciales_atom: -3.080369908268535e-09 -3.014922975854519e-08 0.03651855942116886 -0.009737592012148542
# Finales_atom: -2.0428269451288245e-07 5.870728680147909e-08 -0.036855265820396985 0.006118379565508771
# El átomo sale de la esfera en t = 1.4606293812e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.3701147204176684e-10 -1.935832673271439e-09 -0.0012324238890238448 -0.000682553856040075
# Iniciales_atom: 1.1194034057628353e-08 9.53220200648016e-08 0.009562711783409287 -0.01477137746424866
# Finales_atom: -1.3198816147739936e-08 -1.056859330170161e-07 -0.01766046074192187 -0.06464309221201905
# El átomo sale de la esfera en t = 1.2163805056e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.265453288232545e-09 -1.796932590365069e-09 0.0006179401641834901 0.0007557701156112465
# Iniciales_atom: 2.7016539559199083e-08 6.078470469318479e-08 0.004384280255795552 0.0053242742900819345
# Finales_atom: 2.6270809671785208e-08 4.245967274185433e-10 -0.010341481265340673 -0.004981429868993543
# El átomo sale de la esfera en t = 1.5887884889e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.5921257401825454e-10 -1.351489147237597e-10 -0.0068297773985966145 0.0014582629833685102
# Iniciales_atom: -3.874475457533057e-08 5.381928246044599e-08 -0.001774965647929996 -0.00698097687353798
# Finales_atom: -4.328451748595281e-08 1.2023083076886851e-08 0.21518037778734378 -0.06861693298204223
# El átomo sale de la esfera en t = 1.3055804722e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.2735596793485958e-09 1.3309891405432838e-09 -0.0006271231768688976 0.00027547292432139755
# Iniciales_atom: 4.290884831555267e-08 7.314494788981954e-08 -0.009834898950584904 -0.024553808295896727
# Finales_atom: 7.195177036205852e-08 -3.28383931958254e-08 0.01713013491307098 -0.012629441409982099
# El átomo sale de la esfera en t = 1.2033128423e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.276979214897723e-09 2.251255630049536e-09 -3.68789141882602e-05 -6.534674522423799e-05
# Iniciales_atom: -4.684583845836449e-08 -8.231435730358e-08 -0.0009374121186964965 -0.0015397515348020154
# Finales_atom: 5.958282728081662e-08 1.0480395685856115e-07 -0.0027668570637297595 -0.0049510612221017524
# El átomo sale de la esfera en t = 1.4164886781e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.0849228104447854e-09 3.52943830880762e-09 -0.0006554390455278166 -0.0009391579958907045
# Iniciales_atom: -4.285717810041866e-08 -3.6500688133015576e-08 -0.012038274173873518 -0.026687896999947256
# Finales_atom: 4.9148885159068915e-08 -1.4633497813142568e-07 0.008942190488780614 -0.01199747967654049
# El átomo sale de la esfera en t = 1.6136176523e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -5.958236722160731e-10 1.3791096993498209e-09 0.00040551360442477225 -0.0003476574484104259
# Iniciales_atom: -6.481174129687369e-08 -3.587840428912339e-08 0.0295576748026979 0.0013614689546673532
# Finales_atom: 1.7739981873130762e-07 -1.5056637046012107e-07 0.02765397892154543 -0.017941756965839772
# El átomo sale de la esfera en t = 1.2093119944e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -5.454066709321736e-09 -2.8857597330118825e-09 -0.0004984924120503059 -0.005154727333913095
# Iniciales_atom: 4.4254292226298835e-08 -8.608771377836718e-08 0.018563620825888024 0.02746235763215917
# Finales_atom: -1.3761572519714707e-07 -4.640646751506403e-08 -0.004432917035050517 -0.017114728476284518
# El átomo sale de la esfera en t = 1.4438449751e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 4.74204096313215e-09 4.476553955126137e-09 -0.0027141940358500214 -0.004259463385511825
# Iniciales_atom: -4.77511817111792e-08 -8.44251304851216e-08 -0.011473703996703626 -0.006323028056228059
# Finales_atom: -5.4520343956113454e-08 -1.1568756272541615e-07 -0.010441018801097065 -0.013602430274607127
# El átomo sale de la esfera en t = 8.1380609889e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -5.853770276374075e-09 -2.946445819741015e-09 -0.0020510394014589773 -0.001762126382682353
# Iniciales_atom: 3.384962206038404e-08 -4.322476620102805e-08 0.018790662359571813 0.0078080155065959325
# Finales_atom: 8.962592294737087e-08 1.9393335872954076e-07 0.013730154878525025 0.04054071198205447
# El átomo sale de la esfera en t = 1.5701156528e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.506867048009707e-09 -4.9638004544383955e-09 0.0016898841523301429 -0.0014523549446709095
# Iniciales_atom: -9.800635611665599e-08 -9.054064099595984e-09 0.026755594454471128 0.020939511457506138
# Finales_atom: 1.6608698727733775e-07 2.6375565297620397e-07 0.03734435044078099 0.0474799315782969
# El átomo sale de la esfera en t = 1.1862495230e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.864155765879549e-09 -2.3508736184988535e-09 0.0010108665680521561 -0.0006162290225039293
# Iniciales_atom: 1.8898175258399293e-08 -6.319874894466732e-08 -0.009871612848265463 -0.01622645258160296
# Finales_atom: -2.9564664873531866e-08 1.2982749724446188e-07 -0.004808383142069539 0.055560782470107234
# El átomo sale de la esfera en t = 1.5822817446e-20 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.3265601168882725e-09 -2.9580913611888777e-09 0.0017891693819584967 -0.00023137945888819468
# Iniciales_atom: 2.0264744650199875e-08 -8.140550668934813e-08 -0.02351060599546685 0.023460356712803235
# Finales_atom: -3.7076742020354015e-08 2.0396094063565802e-07 0.0006668518911224575 0.03816506887167429
# El átomo sale de la esfera en t = 1.2590397627e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.04064532540801e-09 -5.267711027198031e-10 0.0014195181211938543 -0.0015153282124502363
# Iniciales_atom: -1.1193527960109309e-08 8.831450541706433e-08 0.012090121497801075 0.0014589548344684051
# Finales_atom: 3.442698015640552e-08 -3.09116671429554e-08 -0.04844842988909767 0.013715217356758617
# El átomo sale de la esfera en t = 1.3271792469e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -4.349735672234504e-10 -6.171047174041804e-09 0.00011646953047762098 -0.0007478358343183039
# Iniciales_atom: -1.6314029997986255e-08 9.684023953010676e-08 0.009325585571957421 0.017286310581537716
# Finales_atom: 7.915181657013129e-08 -1.3040387360882467e-07 -0.0007363492021572619 -0.014090836331575044
# El átomo sale de la esfera en t = 1.5532171767e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 5.0735356048501475e-09 -1.5034373586944891e-09 -0.0023657184848661075 0.0005365758102117308
# Iniciales_atom: -7.327850829750822e-08 2.3755568896639097e-08 -0.0012358231493775705 -0.005935244583243261
# Finales_atom: 1.1035351082653817e-07 -1.9442544941660015e-08 0.08666254561551426 -0.010872909931325845
# El átomo sale de la esfera en t = 1.2310599057e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.9451813021132512e-09 -3.891687304775768e-09 0.004171453030813479 0.0003534192445042374
# Iniciales_atom: 6.743038690468969e-08 6.278380157222668e-08 -0.02206287426327255 0.008523858616132151
# Finales_atom: 7.856907699014111e-08 -6.76052707569873e-08 0.004398867484973767 0.015687483896231796
# El átomo sale de la esfera en t = 1.5807192312e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.5854147168818947e-10 -1.1847754068926023e-09 -8.983875146255523e-05 -0.00022268491367071343
# Iniciales_atom: -2.2696557618901837e-08 -5.8566019758591166e-08 0.004240163263189722 0.008025590246775141
# Finales_atom: -8.68463301580693e-08 -2.937811945336746e-07 -0.007009139375639459 -0.024479803689463647
# El átomo sale de la esfera en t = 1.2386212013e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.4464458090020874e-09 -6.906881868815081e-10 -0.00040114469153494756 -0.0005318476393518202
# Iniciales_atom: -4.11606345327488e-08 7.608353263248897e-08 -0.010643393664034927 -0.03391031610107614
# Finales_atom: -1.9756529608809475e-08 -3.4380767767520654e-07 0.004409007318800958 -0.03688309084841649
# El átomo sale de la esfera en t = 1.2740308223e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.853437503041377e-10 3.0540520089367386e-09 -0.00011823920921555663 0.00027690656635589615
# Iniciales_atom: 7.554207033993504e-08 -4.179777842947407e-08 -0.021079179500855298 0.00014320002892140738
# Finales_atom: -3.985535025197295e-08 -1.948401603513237e-07 -0.012520979638878488 -0.039088603543500036
# El átomo sale de la esfera en t = 1.2029252302e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.824375567630352e-09 -3.310797000121415e-09 0.0033820602984217206 0.001084680250507948
# Iniciales_atom: 8.606371931731622e-08 3.26265525270063e-08 -0.014419161917698138 0.014541088205415949
# Finales_atom: -1.5258749160931393e-08 -7.053463086873529e-08 0.016429431748588425 -0.025421267861068804
# El átomo sale de la esfera en t = 1.6420627065e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.9916470403110863e-10 -6.548995121797854e-10 0.0006771008047946821 -0.001252920657859984
# Iniciales_atom: 1.8264260704711114e-08 -8.661947909900402e-08 0.0020995515163693213 0.011023216931173993
# Finales_atom: 1.0590527690730455e-07 -1.404840757271501e-07 0.00717646580309992 -0.0058884823753420495
# El átomo sale de la esfera en t = 1.2384249799e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.5067485860557476e-09 -2.8036660134610377e-10 0.001191534523936125 0.0005764233681258197
# Iniciales_atom: -6.899784588824638e-09 9.257267045610397e-08 -0.01703454721840896 -0.0014695578389727656
# Finales_atom: 4.796852682542026e-08 -1.266299860113271e-07 0.02297273625967362 -0.026984246407246996
# El átomo sale de la esfera en t = 1.4820281616e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.191894814067918e-09 -3.1616115950009347e-09 0.0029214860846719292 0.0016412229229443953
# Iniciales_atom: 4.721434865923593e-08 8.807659922660063e-08 -0.002324230624884051 0.014714295557064199
# Finales_atom: -8.460617717490406e-08 -8.696137943442634e-08 -0.037085151947138253 -0.046609505016823996
# El átomo sale de la esfera en t = 1.5308822376e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.971017625694131e-10 3.793251839506439e-09 -0.00046143024831138304 0.0016182847604777368
# Iniciales_atom: -3.5329859546767256e-08 -6.834400259751859e-08 0.004762450374886133 -0.017444777571367375
# Finales_atom: 8.465572678981067e-08 2.288358287751913e-08 0.003678198203168099 0.011420054658277218
# El átomo sale de la esfera en t = 1.6986138233e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.2046969853453763e-09 1.1046452739556965e-09 0.0011008872047540484 0.0004206432867695075
# Iniciales_atom: -1.3954556457465265e-08 -5.998395444278034e-08 -0.016048770362872795 -0.012534244450228035
# Finales_atom: -1.5386008074410696e-07 6.012110487475062e-09 0.0025868964308011105 0.004741375941726257
# El átomo sale de la esfera en t = 1.6744310047e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.546896695281906e-09 -5.538628236798666e-09 -0.0009329470084713734 -0.0016237943279590076
# Iniciales_atom: 1.3152951157723488e-08 -8.266117057322267e-08 -0.005272740011157803 -0.0031562076450822887
# Finales_atom: -5.7692413651652146e-08 -8.457677425631322e-08 0.019107307945969352 0.03513857743920819
# El átomo sale de la esfera en t = 1.4684025991e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.0049609650162414e-10 1.9018906087487884e-09 0.0001442685888448526 -0.0002449073931228901
# Iniciales_atom: 7.357052477881617e-08 1.61246740910733e-08 0.020330869550808754 -0.010779881040788118
# Finales_atom: -3.466117813772211e-08 -1.3622105122006338e-07 -0.006514344125661465 0.006518534072298944
# El átomo sale de la esfera en t = 5.5709528414e-22 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.0201968063242117e-09 -1.2220305748423858e-09 0.0009281455153136373 1.4683779207870246e-05
# Iniciales_atom: -8.95385556007723e-08 3.917121050876069e-08 0.02484445580465575 0.007624720994257953
# Finales_atom: 2.40004896318715e-07 3.3577689494565546e-08 0.023708889920451934 -0.0036997095963719113
# El átomo sale de la esfera en t = 1.2780392274e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.8071887791288367e-09 1.3498640917676667e-09 -0.0005160163373106198 -0.0010796689859880989
# Iniciales_atom: -6.086127547573139e-08 3.410030490969934e-09 -0.0049543778954782795 -0.01011912356494827
# Finales_atom: 3.886759416435664e-08 -1.5155009560432972e-07 0.005259701520217296 -0.0034252984104312474
# El átomo sale de la esfera en t = 1.6088290105e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.037185668773596e-09 -2.3771229409312846e-09 0.0014732076894928932 -0.0016108548803755883
# Iniciales_atom: 2.8748748106571218e-08 4.325374190659384e-09 -0.007961416774292646 0.014039644974430152
# Finales_atom: -6.752847633966753e-08 2.0000046377199764e-08 0.005646432574164955 -0.0074867852631909934
# El átomo sale de la esfera en t = 3.1966935203e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 9.83478958886721e-09 -6.648365068972781e-09 -6.929207663583341e-05 -0.005622834751475621
# Iniciales_atom: 2.380856628147247e-08 -9.540708306297613e-08 -0.0388280296939146 -0.005549973590607472
# Finales_atom: -1.0596480651350759e-07 8.148183620471809e-09 -0.03660892433684696 0.02591498857546316
# El átomo sale de la esfera en t = 3.4576342091e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.5668825811663316e-09 -9.530879614923654e-10 0.0009792555277973558 -0.0013893618079113177
# Iniciales_atom: -8.694852142404743e-08 -3.895429005022305e-09 -0.0025400565444002395 0.013580367607368624
# Finales_atom: 1.171206608095261e-07 5.083441844907005e-08 0.022605997669709103 -0.0016042954813050468
# El átomo sale de la esfera en t = 1.4125237156e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 5.3389810750123894e-11 -5.790456831624923e-10 -1.554453838941461e-05 0.003453927271631144
# Iniciales_atom: 1.5379965663944433e-09 -5.916621136598433e-10 -0.00017512373002575438 -0.01169865722407282
# Finales_atom: 8.372682019920089e-11 -6.867074490979173e-08 -0.0002730915709508128 -0.044342704223838
# El átomo sale de la esfera en t = 2.9620006037e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.713514212450142e-10 5.527931367534584e-10 -0.00013841911586555934 -0.0013187504467106264
# Iniciales_atom: 8.527713410497795e-09 6.934138181943826e-08 1.9901314098089455e-05 0.012531581959738277
# Finales_atom: -9.030938025176372e-09 6.22157634922668e-09 7.412290900957283e-05 -0.010175931331137755
# El átomo sale de la esfera en t = 1.5353120535e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -4.226990176087164e-10 6.374446741609037e-10 -4.832570113262282e-05 -0.00040257831649579567
# Iniciales_atom: -6.573865896724918e-08 7.533931152452574e-08 0.004609037198577172 -0.012717255452669479
# Finales_atom: -1.5903955301960587e-07 9.801611929537774e-09 -0.016643628469300308 -0.0020157066447542902
# El átomo sale de la esfera en t = 1.2684530066e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 5.054352708439432e-10 2.7787126969048095e-09 -0.0005320468655640863 -2.6632630369893828e-05
# Iniciales_atom: -7.641756947427572e-08 -5.906454813137854e-08 0.029181126639344253 -0.002769730970373096
# Finales_atom: 1.791715151485926e-07 1.449330881823176e-07 0.003883509058163621 0.013738804311430625
# El átomo sale de la esfera en t = 1.3389610538e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.7157266123898658e-09 7.697415697607358e-10 -0.00029727368995606995 -0.0009959655543041132
# Iniciales_atom: 9.601149511285741e-08 -2.793554919698591e-08 0.015045232448805434 0.0015731988695614546
# Finales_atom: 3.8747547355610076e-08 5.97636332948359e-08 0.0036015124683032762 0.017768310846957788
# El átomo sale de la esfera en t = 9.8458966683e-22 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.1904800292320956e-09 -2.8113027966379327e-09 -0.000877568886488997 -0.0002453693727255701
# Iniciales_atom: -9.831532636874815e-08 1.7618690877801916e-08 -0.026433351279947094 -0.005904614792004867
# Finales_atom: 9.909657090499932e-08 -1.0966362643623637e-07 0.009224237885556442 0.0011023421118222473
# El átomo sale de la esfera en t = 4.9749571818e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.8257317171441797e-09 1.2738299619075242e-09 -0.001302075493866382 0.0018327236800271631
# Iniciales_atom: -1.456168863944608e-09 4.5608144661665795e-08 0.014996221848823425 -0.005562357237651294
# Finales_atom: -2.8560153892569397e-09 -1.429635378564566e-07 -0.0048354371456748625 -0.0200703106212871
# El átomo sale de la esfera en t = 4.5671120492e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 8.25787724714824e-11 -1.6457361865065097e-09 0.00019039629706442835 0.00038384632493996304
# Iniciales_atom: -8.234119768705196e-09 3.9368013534699924e-08 -0.015138047766324663 -0.0025752458694328715
# Finales_atom: -2.478987409215381e-07 -9.250787692267738e-08 -0.0200223246759957 -0.009927205664671174
# El átomo sale de la esfera en t = 1.5200566282e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 4.78132407388219e-09 -4.7808487993418055e-09 0.004300847608018996 0.0023218646345018385
# Iniciales_atom: 3.525655053947267e-08 9.261047641822154e-08 -0.032792031709621514 -0.006683767098821285
# Finales_atom: 1.130294736897241e-07 7.973322147104251e-08 0.009398364277272248 0.02443349834337947
# El átomo sale de la esfera en t = 1.3329768598e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.6684912999552968e-09 7.906726312451427e-10 0.0006099180946718048 -0.0001621598006853745
# Iniciales_atom: 4.562798013266954e-08 -2.41850433816378e-08 0.004417434309283923 -0.0014192755166907167
# Finales_atom: 2.379215110974227e-08 5.840533261363546e-09 -0.0035767045481670864 0.0011125563402741782
# El átomo sale de la esfera en t = 1.6744894030e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.2795411835621535e-09 -2.830234599776495e-10 -4.292475225492454e-06 -0.000357814560565437
# Iniciales_atom: 9.460330317055453e-08 -5.506061430044143e-09 0.011108105589443211 -0.004572125570310375
# Finales_atom: -6.501356551431536e-08 -8.199024790730828e-09 0.011269487596964788 0.007582462248941321
# El átomo sale de la esfera en t = 2.9340635065e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.385301779747196e-09 -1.8194497969344878e-09 -0.002013056081590377 -0.0014317302359917925
# Iniciales_atom: 4.376031169868186e-08 -6.849192006080171e-08 0.0307112356798661 -0.01236725026821301
# Finales_atom: 3.459618359400996e-09 9.556922647570338e-08 -0.01689489087297171 0.046128934769813515
# El átomo sale de la esfera en t = 1.6386082569e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -5.90215200912577e-10 2.9433734688130255e-09 0.001423002578841975 0.00038929465703565103
# Iniciales_atom: -9.706585467286748e-08 1.529115910087146e-08 0.023402057127875662 -0.018596105277110954
# Finales_atom: 3.036502676817655e-07 -3.0062150884759e-08 0.038355674349505584 0.0013304955426333227
# El átomo sale de la esfera en t = 1.2688066531e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -4.779564600617589e-09 6.620694343526892e-10 0.0003330031010116998 0.002288949012808927
# Iniciales_atom: -5.669458769697455e-08 4.817561166572822e-08 -0.018315641955057103 -0.0026549624661559926
# Finales_atom: 4.652391605546429e-08 -7.571494046902632e-08 0.034172754678248846 -0.02743972753879471
# El átomo sale de la esfera en t = 1.5887467777e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.792908257411746e-10 -1.8541693974283855e-09 -1.23082368898666e-06 -0.0002246340326393331
# Iniciales_atom: 9.164996408841869e-08 3.9618214067838094e-08 0.00333939767943694 -0.01237033867928788
# Finales_atom: -9.707195066295182e-08 -1.7083780207795168e-07 -0.013387560856023955 -0.010541939120531037
# El átomo sale de la esfera en t = 3.0969581961e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.3603720586229052e-09 6.526493914726408e-10 -0.001539273717639432 0.0006566017892349247
# ...
# Iniciales_atom: 8.976218725873043e-08 4.4017923387802914e-08 -0.005948731181214638 -0.02674511984017104
# Finales_atom: -9.593670050823166e-08 -7.032146410534227e-08 0.015274691251739102 0.03226934887513701
# El átomo sale de la esfera en t = 1.2463702456e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 8.470580001508709e-10 -3.357498612423399e-10 -0.001750207199689104 0.0012037247954082204
# Iniciales_atom: -9.567238531997287e-08 2.8261062708595183e-08 -0.006874226584169019 0.004765109442755289
# Finales_atom: -5.901181872595749e-08 6.003307841490645e-08 0.02694878161242211 -0.02280051440182904
# El átomo sale de la esfera en t = 3.0475359223e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.4172542641843107e-10 3.477600206041997e-11 0.0014617222974853414 -0.00026136288433545134
# Iniciales_atom: -9.361314574534283e-08 -2.547620145482181e-08 0.019094815616295946 -0.008003625160333698
# Finales_atom: 7.448930043644007e-08 -9.558362616040281e-08 0.009853335841412035 0.0039864336190895714
# El átomo sale de la esfera en t = 1.2198389739e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -6.086850095730173e-09 -3.3673800236657436e-09 0.0002861114538226378 0.0007033867635635358
# Iniciales_atom: 8.151689004076836e-08 5.693785074148891e-08 0.010816274602742308 0.001195612098233931
# Finales_atom: -1.9154287301728982e-07 -1.5474455205508622e-07 -0.021511641565023276 -0.015101743856769764
# El átomo sale de la esfera en t = 3.2356563628e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -7.999242643068939e-10 -1.3247905893160787e-09 -0.0007042068535870927 -0.0010048843524760103
# Iniciales_atom: -4.040339591607812e-08 -4.155758241305784e-08 0.008282740215848027 0.0038287346475189147
# Finales_atom: -2.010567997632599e-07 -3.4230353118468917e-07 -0.021000288837152045 -0.03671190458702371
# El átomo sale de la esfera en t = 1.2206370344e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -8.007932833229334e-10 -2.4654314506756737e-09 -0.0009114145673916906 -0.003229982004217598
# Iniciales_atom: 2.6605146933382053e-08 -8.66539820535774e-09 0.006637223504470949 0.021657273338299306
# Finales_atom: -3.9171170364532304e-08 6.855604758490756e-08 -0.011031434414152712 0.0033396984616963082
# El átomo sale de la esfera en t = 1.4506804985e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.0810660648880298e-10 -1.915613319096033e-10 0.000484375720136756 0.00011095458994549761
# Iniciales_atom: 8.51419665665378e-09 9.852546509321603e-08 -0.006262715675682393 0.019361341674553854
# Finales_atom: -7.772229698018082e-08 1.437833082683924e-07 -0.0035066401065813667 -0.0035514878822945754
# El átomo sale de la esfera en t = 8.2472575861e-22 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.781909873885557e-10 1.2882769157365872e-09 -0.0003918517445857093 -0.001872559202486765
# Iniciales_atom: 7.2171405839213356e-09 9.962067411229358e-08 0.001954518179763814 -0.0072863115039585695
# Finales_atom: -9.81450222715973e-09 -1.8657371684953973e-07 -0.0023266921087142043 -0.016439197675224827
# El átomo sale de la esfera en t = 1.3660791888e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 5.557211608830242e-10 -9.304531787860504e-10 0.0001787588039824228 0.0011599598358208994
# Iniciales_atom: -4.769563582168402e-09 4.4793976961626496e-08 0.007627797572888122 0.021826105608988244
# Finales_atom: 1.4097306710728493e-07 2.5867566205176803e-07 0.014921384065608993 0.02407499563548696
# El átomo sale de la esfera en t = 1.5494113939e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -3.2623253761956263e-09 7.431662682283611e-10 0.0015866538777682207 6.881911732553312e-05
# Iniciales_atom: 9.633980100618568e-08 -8.578436763399797e-09 0.015265196038914639 0.00766149578922483
# Finales_atom: 1.2732857553651978e-07 1.8339922798029676e-07 0.008840068934036464 0.01983177621460378
# El átomo sale de la esfera en t = 1.5671747236e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 5.146665853601464e-10 1.1994136258941553e-10 -0.0010073963305613654 -0.00036812437856746834
# Iniciales_atom: -5.348199487869105e-08 -1.8888890375073858e-08 -0.015907915377976898 -0.006360731495217898
# Finales_atom: -3.3587755291189e-07 -1.3776434470798097e-07 -0.033081897970001876 -0.01369221801199759
# El átomo sale de la esfera en t = 1.5950716420e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 8.648971442406297e-10 6.22737298835902e-09 -0.00033031618468531775 0.0003029689355438202
# Iniciales_atom: -7.283383196061529e-08 -6.774457430637509e-08 0.008853059708621783 -0.023044704328281134
# Finales_atom: 3.0748269926037676e-07 7.608023755539168e-08 0.039394185506674805 0.016970464021184215
# El átomo sale de la esfera en t = 1.5420063935e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.6173664540258211e-09 -2.8803605889468346e-09 -0.0010169426996267667 0.0025781224396263457
# Iniciales_atom: 2.6194962872509046e-08 7.71403517765737e-08 0.023957268378970886 -0.014765552604508674
# Finales_atom: -1.7811475919875488e-07 -8.825814766123848e-08 -0.03827315964022774 -0.007408420053126658
# El átomo sale de la esfera en t = 1.5254484346e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.2541667297641164e-10 -1.086090200087301e-09 -0.0020816120409098584 -0.003964747778039024
# Iniciales_atom: -6.398941016829043e-09 -9.367928804825436e-08 0.023270411471564226 0.016520347247003485
# Finales_atom: -1.196724237315645e-07 7.682913850822815e-08 -0.03595131857088265 0.005006729956255879
# El átomo sale de la esfera en t = 1.4423828862e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.2102527895098766e-08 -1.2524418331479003e-08 0.001461923060716219 -0.0018451843334958713
# Iniciales_atom: -3.348382230562032e-08 2.5646183914635413e-08 -0.025873908210191972 0.026610975373346103
# Finales_atom: -3.057888053154656e-08 2.7910125867247233e-08 -0.06827832183543671 0.06648319170557504
# El átomo sale de la esfera en t = 1.7093332216e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.3869338110348583e-09 -1.8044662808442454e-09 0.001661341024533835 -0.0005515689668868181
# Iniciales_atom: -9.53634482481155e-08 -2.7562548256318885e-08 0.016653278707702463 0.026708576493309967
# Finales_atom: 4.539254441910323e-08 2.715900973288441e-07 0.013096269081872256 0.03144907305241796
# El átomo sale de la esfera en t = 1.1938476128e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.7310694757735536e-10 2.436925746800268e-09 0.0014230135953550234 -0.001052511354926216
# Iniciales_atom: 2.7222674585542892e-08 9.608970766295289e-08 -0.011533215844862109 -0.003829913156450514
# Finales_atom: -9.580954421572352e-08 -7.1614941861301e-08 -0.01718862290437927 -0.02432760849591439
# El átomo sale de la esfera en t = 1.4000434033e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.3415304375809565e-09 -1.875393222543291e-09 -0.0005284510223662268 -0.00011249306560672163
# Iniciales_atom: -5.66216001845885e-08 -8.111629103194507e-08 0.0015560162417768328 0.006523158901664582
# Finales_atom: -2.6499982541118472e-08 7.773925546528646e-08 -0.0018258101450140734 0.013743969646156672
# El átomo sale de la esfera en t = 1.4727709925e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.435748628438255e-10 1.538943844764452e-09 0.001228432714071018 -0.0008809867687106011
# Iniciales_atom: -2.4548942093996495e-08 9.31300847796697e-08 -0.0014597148829378196 -0.006791687056780429
# Finales_atom: -9.783142681237642e-08 9.885822715301994e-08 -0.05058229834910746 0.04746025358218338
# El átomo sale de la esfera en t = 1.3727840400e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -6.6737710297679444e-09 -2.077537293236826e-09 -0.0006755083355106184 -0.0010844290874455881
# Iniciales_atom: 7.400005665681459e-08 -1.524759030072421e-08 0.022652083872963264 0.018167443993734857
# Finales_atom: -1.7309710768739884e-07 -5.398639289148309e-08 -0.0059056602600442605 -0.01076606106868867
# El átomo sale de la esfera en t = 1.6781355281e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 4.42631773238985e-09 -2.41003525731311e-10 0.0007981010429138743 -0.0009786689659525287
# Iniciales_atom: -5.8074960294019565e-08 -8.073945445721836e-08 -0.016011173208794506 0.0026077486407554617
# Finales_atom: -1.1815621252254473e-07 2.663113256901506e-07 -0.020471870627195812 0.05749717548902814
# El átomo sale de la esfera en t = 4.4333506437e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.3654035815846744e-09 -2.2540095037940115e-09 0.0015579299083006066 -0.003045097459642177
# Iniciales_atom: 8.295466553863154e-08 3.016997799757847e-08 -0.017423039079832094 0.020703073704129337
# Finales_atom: -3.0436827340198077e-07 -1.3166103199839846e-07 -0.053672600421803114 -0.031136637404410684
# El átomo sale de la esfera en t = 1.4386450054e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.803554063071558e-09 1.805498329084931e-09 0.0010482796591322289 1.1015552712728086e-05
# Iniciales_atom: 9.822797178809957e-08 -1.7768821080491405e-08 0.01312561412096824 0.005730864128930625
# Finales_atom: 1.4222772845928439e-07 1.3300296679467432e-07 -0.0009981817403976012 0.005001082731724212
# El átomo sale de la esfera en t = 1.5774603422e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.9084214410247725e-09 -2.90106274406203e-10 0.0007078597745772999 0.0019374066888386526
# Iniciales_atom: -7.685676933189134e-08 -6.393670696569954e-08 0.00979254544798799 0.00043334083222617333
# Finales_atom: 7.174902929175522e-08 -4.735491873107938e-08 0.015303072009467967 4.306976429620138e-05
# El átomo sale de la esfera en t = 1.3496760689e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -8.566465853425252e-10 -2.9327577596289322e-09 0.0005940068084118528 6.016545645830227e-05
# Iniciales_atom: 1.1460935972290464e-08 4.25407156458385e-08 -0.019049798457628976 0.01087001049822758
# Finales_atom: -8.748667363631541e-08 -4.580851177917347e-08 0.007674479616940483 -0.0061924701598455156
# El átomo sale de la esfera en t = 1.5989179214e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 6.834007242200091e-11 1.5732298898801364e-09 0.0004237522365671876 -0.0002634679034434731
# Iniciales_atom: -8.77556161003153e-08 -2.3991224162124953e-08 0.016874568817837853 0.012486579538022045
# Finales_atom: 1.2465880574280315e-07 4.7830485552408436e-08 -0.0017859514094477297 -0.006089553401184849
# El átomo sale de la esfera en t = 1.3314282946e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 8.488944609753037e-10 -3.6991766474615773e-09 -0.00024131637612691248 0.0018581187679682118
# Iniciales_atom: 4.747229486802988e-08 4.644563816708731e-08 0.02093754470343468 -0.0018837735246021758
# Finales_atom: 2.405806920322444e-09 -7.644069695945521e-08 -0.013333809276957185 -0.024921649108631216
# El átomo sale de la esfera en t = 1.6162573788e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.6655937138883935e-09 -2.3655795178810742e-09 -0.0006510641220622462 -0.0006212513230143104
# Iniciales_atom: -4.6843051679860365e-08 -4.0475778208305333e-08 -0.012751109171092621 -0.03302287014789135
# Finales_atom: 4.242282564818141e-08 -1.1726283716636904e-07 -0.0038518892696256905 0.036821495842056184
# El átomo sale de la esfera en t = 2.5602072746e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.8085071219584734e-10 -1.4514672669922106e-09 -4.37983721397731e-06 -0.0006592628345261119
# Iniciales_atom: -9.284881108842868e-08 -1.1236368462299499e-08 0.01854366129404516 -0.009326003501656745
# Finales_atom: 9.83314128051757e-08 -1.4541511177432416e-07 0.01228020167943984 -0.007264601959320177
# El átomo sale de la esfera en t = 1.2935188671e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -1.1758174563711574e-09 7.896762254076043e-10 -0.0012496671992477412 0.0013135719277695764
# Iniciales_atom: 5.3254485331015513e-08 -6.1479458308663496e-09 -0.011055319071783335 -0.01002988846610032
# Finales_atom: 5.763487638724996e-08 -1.7813386291229207e-07 0.0023166295126702853 -0.017366583089860357
# El átomo sale de la esfera en t = 1.2433916766e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 1.2939877907282211e-09 -4.9733689718228694e-09 -0.0040140385050748415 0.008759382932567675
# Iniciales_atom: -7.56282606748187e-08 4.402136784069074e-08 -0.011598798253131436 -0.008378803549494366
# Finales_atom: 1.7168955716313812e-08 -3.8166598068397075e-08 0.12654934260710549 -0.20212881541225286
# El átomo sale de la esfera en t = 3.2464342626e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -8.66123507117758e-10 -3.901277221357665e-09 0.00036007689395133535 0.0009190980305332735
# Iniciales_atom: 2.138341047720884e-08 9.104823292623129e-08 0.005849743600212062 0.03834481479209696
# Finales_atom: -1.7663726925375015e-08 5.0007141189777375e-08 -0.0031245460335549194 -0.006567264087644321
# El átomo sale de la esfera en t = 1.9053745916e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.862060337304204e-09 1.9722942295303145e-09 0.0011278048360793325 -0.0008737322574358072
# Iniciales_atom: 6.578551000426535e-08 -1.9231876481994785e-08 0.019097957260405023 0.011347977506040469
# Finales_atom: -1.2821470635025446e-07 -6.237046039575291e-08 -0.017288343257994516 -0.0170446997481385
# El átomo sale de la esfera en t = 1.5721665171e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -2.1969201971056115e-09 5.296296784415508e-10 0.004203880433044242 -0.00013344114189526375
# Iniciales_atom: -3.782631238238782e-08 8.221186488118651e-08 -0.008172953957037103 -0.0004001754576454028
# Finales_atom: -8.215121485117601e-08 -2.559760514267369e-08 -0.02908019716035047 -0.01801353337434336
# El átomo sale de la esfera en t = 1.6301772453e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: -8.909759406076759e-10 4.164043909067384e-09 0.00048080292637636734 -0.00042625957461489734
# Iniciales_atom: -4.142476488565953e-08 1.7357543113672148e-08 0.00725597869849497 -0.020739405874421777
# Finales_atom: 2.1958641682372074e-07 -3.2286447734092283e-07 0.036288339882626794 -0.049832740683934416
# El átomo sale de la esfera en t = 2.8309562325e-21 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.3297084653020718e-09 7.002104070241896e-11 -0.0009331782902223841 0.0010219435286138363
# Iniciales_atom: 9.049501013279483e-08 2.7067911177867197e-08 0.007641284014996533 -0.010257055416692121
# Finales_atom: -9.252458371216951e-08 -8.355177073925029e-08 -0.011986636687901495 0.002097811220900585
# El átomo sale de la esfera en t = 4.6913444615e-06 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 3.6184530282581964e-09 -2.1094421258046887e-09 -0.0005690372979986293 0.0002915614528884122
# Iniciales_atom: -7.664736191103892e-08 3.4129568802143526e-08 -0.0040519639118793485 -0.0037213139678528655
# Finales_atom: 7.28228173709497e-08 -9.73238294910978e-08 0.005393600714984778 -0.001342029145109205
# El átomo sale de la esfera en t = 1.0018454587e-21 s con interpolación
# Iniciales_ion: 0.0 0.0 0.0 0.0
# Finales_ion: 2.7551971617429878e-09 -5.883492107481595e-10 -0.003378545190152505 -0.0015198472231106215
# Iniciales_atom: -9.439380642256457e-08 2.2481878073303975e-08 0.0023721380526643397 0.01936508981976565
# Finales_atom: 1.0126748889847412e-07 -1.1040019706455933e-07 0.014670494173257099 -0.03305909989522601
# El átomo sale de la esfera en t = 1.6134869670e-06 s con interpolación
# 1.6134869670246774e-06
# /home/quantic_user/.local/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/quantic_user/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def radio (x, y, z):
    radio = math.sqrt(x**2 + y**2 + z**2)
    return radio 


for i, results in enumerate (all_results):   #cada colision en numero de trayectorias
    for j, result in enumerate (results):     #parametros de cada colision
        t_sol=result[0]
        ionx_sol=result[1]
        iony_sol=result[2]
        ionz_sol=result[3]
        ionvx_sol=result[4]
        ionvy_sol=result[5]
        ionvz_sol=result[6]
        atomx_sol=result[7]
        atomy_sol=result[8]
        atomz_sol=result[9]
        atomvx_sol=result[10]
        atomvy_sol=result[11]
        atomvz_sol=result[12]

        plt.plot(ionx_sol, iony_sol)
        print('Iniciales:', ionx_sol[0], iony_sol[0], ionvx_sol[0], ionvy_sol[0] )
        print('Finales:', ionx_sol[-1], iony_sol[-1], ionvx_sol[-1], ionvy_sol[-1])
        print("Tiempo_resonancia", )
        plt.plot(atomx_sol, atomy_sol)
        plt.xlim(-2E-7, 2E-7)
        plt.ylim(-1E-6, 1E-6)
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.show()
# Out:
# Iniciales: 0.0 0.0 0.0 0.0
# Finales: -1.5994373467536689e-09 2.9075275692337734e-09 0.0016469389402299162 -0.0002252902205190047
# Tiempo_resonancia
# Iniciales: -1.5994373467536689e-09 2.9075275692337734e-09 0.0016469389402299162 -0.0002252902205190047
# Finales: -2.0275015744445403e-09 7.509535753563858e-10 -0.00036818429709491326 0.002775949020153108
# Tiempo_resonancia
# Iniciales: -2.0275015744445403e-09 7.509535753563858e-10 -0.00036818429709491326 0.002775949020153108
# Finales: -3.2068723353453656e-09 -4.5600303682870324e-09 -0.0018864450167169501 0.0018839912107906603
# Tiempo_resonancia
# Iniciales: -3.2068723353453656e-09 -4.5600303682870324e-09 -0.0018864450167169501 0.0018839912107906603
# Finales: 3.189868699169862e-10 -5.647566283384179e-09 -0.002800857820004224 -0.0015635549810532607
# Tiempo_resonancia
# Iniciales: 3.189868699169862e-10 -5.647566283384179e-09 -0.002800857820004224 -0.0015635549810532607
# Finales: -4.233027108954525e-09 -2.0047842579329945e-09 -0.0036733887522313663 -0.004367225507224403
# Tiempo_resonancia
# Iniciales: 0.0 0.0 0.0 0.0
# Finales: 9.004293458456821e-10 -3.063142549416391e-09 0.000920833792344905 -0.0026538872025108603
# Tiempo_resonancia
# Iniciales: 9.004293458456821e-10 -3.063142549416391e-09 0.000920833792344905 -0.0026538872025108603
# Finales: -1.916611874423618e-09 2.964873575373971e-09 0.0007119658504612198 0.0004455936016242572
# Tiempo_resonancia
# Iniciales: -1.916611874423618e-09 2.964873575373971e-09 0.0007119658504612198 0.0004455936016242572
# Finales: -4.1728997105816185e-09 1.5879084995434394e-09 0.00042706798838940086 0.0016234191112228461
# Tiempo_resonancia
# Iniciales: -4.1728997105816185e-09 1.5879084995434394e-09 0.00042706798838940086 0.0016234191112228461
# Finales: -4.565628500882565e-09 -5.998206071258546e-09 -0.00188399605567238 0.005659919139219604
# Tiempo_resonancia
# Iniciales: -4.565628500882565e-09 -5.998206071258546e-09 -0.00188399605567238 0.005659919139219604
# Finales: -9.951900908085373e-10 -9.995806301487539e-09 -0.005453357583779423 0.0022495849234023335
# Tiempo_resonancia

# %%
#Debe graficarse en relación al tiempo
R = []
for i in range(1000):
  R.append(np.sqrt((atomx_sol[i] - ionx_sol[i])**2 + (atomy_sol[i] - iony_sol[i])**2 + (atomz_sol[i] - ionz_sol[i])**2))

# %%
plt.plot(R)
plt.grid()

# %%
from scipy.interpolate import CubicSpline
x_grid = np.linspace(0,1000,1000)
R_t = CubicSpline(x_grid,R)
x_grid2 = np.linspace(0,1000,1000000)
R2 = R_t(x_grid2)
plt.plot(x_grid2, R2)
plt.grid()

# %%
#AAplicación FFT
N = len(R2)
y_fft= np.fft.fft(R2)
x_fft= np.fft.fftfreq(len(R2))[:N//2]

#Graficas en dominio de frecuencias
plt.plot(x_fft, np.abs(y_fft[:N//2]))
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e-6, 1e-3)
plt.xlabel('Frecuencia')
plt.ylabel('Amplitud')
plt.title('Espectro de frecuencias')
plt.grid()
plt.show()

# %%
import numpy as np
import math
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import random
from multiprocessing import Pool, cpu_count
import time
import logging

#Ion: Yb+ , atom: Li

#constants
m_ion = 2.8733965E-25  #(YB+)
m_atom = 1.1525801E-26 # (Litio)
C4=5.607E-57  
C6=5E-19 * C4   
frf = 2.5 * 10**6
Omega = 2 * np.pi * frf
a = -2.982E-4  
q = 0.1       
T_ion = 0    
T_atom = 0.1E-6 
r0 = 0.1E-6  # Radio de la esfera
ti = 0
tf = 10E-6   
dt = 1000
ptol = 1e-10
num_cpus = 24
num_solution = 10
num_collisions = 500

logging.basicConfig(level=logging.INFO)

def system(t, y, a, q, Omega, C4, C6, m_ion, m_atom):
    ionx, iony, ionz, ionvx, ionvy, ionvz, atomx, atomy, atomz, atomvx, atomvy, atomvz = y
    dydt = np.zeros_like(y)
    
    # Velocidades del ion
    dydt[0] = ionvx
    dydt[1] = ionvy
    dydt[2] = ionvz

    # Velocidades del átomo
    dydt[6] = atomvx
    dydt[7] = atomvy
    dydt[8] = atomvz

    # Potencial para el ion
    dydt[3] = -(a+2*q*np.cos(Omega*t)) * ionx * (Omega**2 / 4)
    dydt[4] = -(a+2*q*np.cos(Omega*t)) * iony * (Omega**2 / 4)
    dydt[5] = -(2*a+2*-q*np.cos(Omega*t)) * ionz * (Omega**2 / 4)

    # Interacción entre ion y átomo
    r = np.sqrt((atomx - ionx)**2 + (atomy - iony)**2 + (atomz - ionz)**2)
    
    dydt[3] += -(2*C4/r**5 - 6*C6 / r**7) * (ionx - atomx) / (m_ion * r)
    dydt[4] += -(2*C4/r**5 - 6*C6 / r**7) * (iony - atomy) / (m_ion * r)
    dydt[5] += -(2*C4/r**5 - 6*C6 / r**7) * (ionz - atomz) / (m_ion * r)

    dydt[9] += -(2*C4/r**5 - 6*C6 / r**7) * (atomx - ionx) / (m_atom * r)
    dydt[10] += -(2*C4/r**5 - 6*C6 / r**7) * (atomy - iony) / (m_atom * r)
    dydt[11] += -(2*C4/r**5 - 6*C6 / r**7) * (atomz - ionz) / (m_atom * r)

    return dydt

# Funciones auxiliares
def position_on_sphere(radius):
    phi = 2 * np.pi * np.random.rand()
    theta = np.arccos(2 * np.random.rand() - 1)
    x = radius * np.sin(theta) * np.cos(phi)
    y = radius * np.sin(theta) * np.sin(phi)
    z = radius * np.cos(theta)
    return x, y, z

def velocidad_atom(temperature, mass):
    kb = 1.380649e-23
    v_r = -abs(np.random.weibull(2) * np.sqrt(2 * kb * temperature / mass))
    phi = 2 * np.pi * np.random.rand()
    theta = np.arccos(2 * np.random.rand() - 1)
    v_x = v_r * np.sin(theta) * np.cos(phi)
    v_y = v_r * np.sin(theta) * np.sin(phi)
    v_z = v_r * np.cos(theta)
    return v_x, v_y, v_z

def velocidad_ion(temperature, mass):
    kb = 1.38064E-23
    v = np.sqrt((2 * kb * temperature) / mass) * random.gauss(0, 1)
    return v

# Vector de tiempo
t_span = (ti, tf)

# Simulación
def run_simulation(i):

    ionx_0, iony_0, ionz_0 = 0.0, 0.0, 0.0
    ionvx_0, ionvy_0, ionvz_0 = velocidad_ion(T_ion, m_ion), velocidad_ion(T_ion, m_ion), velocidad_ion(T_ion, m_ion)
    atomx_0, atomy_0, atomz_0 = position_on_sphere(r0)
    atomvx_0, atomvy_0, atomvz_0 = velocidad_atom(T_atom, m_atom)
    y0 = [ionx_0, iony_0, ionz_0, ionvx_0, ionvy_0, ionvz_0, atomx_0, atomy_0, atomz_0, atomvx_0, atomvy_0, atomvz_0]

    salida_times = []

    for collision in range(num_collisions):
        solution = solve_ivp(system, t_span, y0, t_eval=np.linspace(t_span[0], t_span[1], dt), method='RK45', args=(a, q, Omega, C4, C6, m_ion, m_atom), rtol=ptol)

        ionx_sol, iony_sol, ionz_sol = solution.y[0], solution.y[1], solution.y[2]
        atomx_sol, atomy_sol, atomz_sol = solution.y[6], solution.y[7], solution.y[8]
        t_sol = solution.t

        for k, t in enumerate(t_sol):
            r = np.sqrt((atomx_sol[k] - ionx_sol[k])**2 + (atomy_sol[k] - iony_sol[k])**2 + (atomz_sol[k] - ionz_sol[k])**2)
            if r >= r0:
                salida_times.append(t)
                break  # Salir del bucle una vez que el átomo sale de la esfera

        # Actualizar condiciones iniciales para la siguiente colisión
        atomx_0, atomy_0, atomz_0 = position_on_sphere(r0)
        atomvx_0, atomvy_0, atomvz_0 = velocidad_atom(T_atom, m_atom)
        y0 = [ionx_sol[-1], iony_sol[-1], ionz_sol[-1], ionvx_0, ionvy_0, ionvz_0, atomx_0, atomy_0, atomz_0, atomvx_0, atomvy_0, atomvz_0]

    return salida_times

if __name__ == '__main__':
    logging.info("Inicio de la ejecución")
    start_time = time.time()

    with Pool(processes=num_cpus) as pool:
        all_salida_times = pool.map(run_simulation, range(num_solution))

    # Unir los resultados de todas las simulaciones
    all_times = [time for sublist in all_salida_times for time in sublist]

    # Calcular el tiempo medio y la desviación estándar
    mean_time = np.mean(all_times)
    std_dev_time = np.std(all_times)

    print(f"Tiempo medio de salida: {mean_time:.2e
# Out:
#   Cell In [17], line 138
#     print(f"Tiempo medio de salida: {mean_time:.2e
#           ^
# SyntaxError: unterminated string literal (detected at line 138)

# %%
#Cambiando Q=0.05 roja
#Con radiofrecuencia de 4.5 * np.pi * 10**6 q=0.1 (#13 minutos)
#C6= 5.607E-56
#q= 0.1
#Le alta estructura a la trampa para el ion en relación al
import numpy as np
import math
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import random
from mpl_toolkits.mplot3d import Axes3D
from multiprocessing import Pool, cpu_count
import time
import logging

#Ion: Yb+ , atom: Li

#constants
m_ion = 2.8733965E-25  #(YB+) 2,8733965 × 10^-25 kg (SR+ 2.83E-25)
m_atom = 1.1525E-26 # (LITIO) 1,1525801 × 10^-26 kg (RB 1.44E-25 )
C4=5.607E-57 #C4=5.607E-57   Paper Prospects #C4=1.1E-56 RbSr+
C6=5E-19 * C4   #C6=5.0E-19     Paper Prospects (LIYB+) C6 = 2.803 × 10−75 Jm6 C4 = 2.803 × 10−57
frf = 2.5 * 10**6
Omega= 2.0 * np.pi * frf #MHz #Depende tambien mucho de esta fase
a = -2.982E-4  #-3E-7, da un buen comportamiento
q = 0.05    #Entre 0.1 y otro
T_ion =  0 # da un buen comportamiento  0.5 milikelvin   Paper Ziv Meir (de Jesus)
T_atom = 0.1E-6  #0.1E-6, da un buen comportamiento   #6 microkelvin (mucho más frio átomo que ion) Paper Ziv Meir
r0 = 0.1E-6
ti= 0.0
tf= 200E-6          #0.001, da un buen comportamiento pal ion #de matlab 200e-6;
dt= 10000
ptol = 1e-10
kB = 1.38064E-23
num_cpus = 24
num_solution = 5
num_collisions = 10

logging.basicConfig(level=logging.INFO)

def system(t, y, a, q, Omega, C4, C6, m_ion, m_a):

    ionx, iony, ionz, ionvx, ionvy, ionvz, atomx, atomy, atomz, atomvx, atomvy, atomvz = y

    # Definición de las ecuaciones diferenciales
    dydt = np.zeros_like(y)

    #Velocidades del ion
    dydt[0] = ionvx
    dydt[1] = ionvy
    dydt[2] = ionvz

    #velocidades del átomo
    dydt[6] = atomvx
    dydt[7] = atomvy
    dydt[8] = atomvz

    #Potencial para el ion
    dydt[3] = -(a+2*q*np.cos(Omega*t))*ionx*(Omega**2 / 4)
    dydt[4] = -(a+2*q*np.cos(Omega*t))*iony*(Omega**2 / 4)
    dydt[5] = -(2*a+2*-q*np.cos(Omega*t))*ionz*(Omega**2 / 4)

    #Interacción con el potencial atom
    r = np.sqrt((atomx - ionx)**2 + (atomy - iony)**2 + (atomz - ionz)**2)

    dydt[3] += -(2*C4/r**5 -6 *C6 / r**7) * (ionx - atomx) / (m_ion * r)
    dydt[4] += -(2*C4/r**5 -6 *C6 / r**7) * (iony - atomy) / (m_ion * r)
    dydt[5] += -(2*C4/r**5 -6 *C6 / r**7) * (ionz - atomz) / (m_ion * r)

    dydt[9] += -(2*C4/r**5 -6 *C6 / r**7) * (atomx - ionx) / (m_atom * r)
    dydt[10] += -(2*C4/r**5 -6 *C6 / r**7) * (atomy - iony) / (m_atom * r)
    dydt[11] += -(2*C4/r**5 -6 *C6 / r**7) * (atomz - ionz) / (m_atom * r)

    return dydt

#Funciones
def position_on_sphere(radius):
    phi = 2 * np.pi * np.random.rand()
    theta = np.arccos(2 * np.random.rand() - 1)
    # Convertir a coordenadas cartesianas
    x = radius * np.sin(theta) * np.cos(phi)
    y = radius * np.sin(theta) * np.sin(phi)
    z = radius * np.cos(theta)
    return x, y, z

def velocidad_atom(temperature, mass, x, y, z):
    phi = 2 * np.pi * np.random.rand()
    theta = np.arccos(2 * np.random.rand() - 1)

    kb = 1.380649e-23  # Constante de Boltzmann en m^2 kg s^-2 K^-1

    # Spherical velocities
    v_theta = np.sqrt((2 * kb * temperature) / mass) * random.gauss(0, 1)
    v_phi = np.sqrt((2 * kb * temperature) / mass) * random.gauss(0, 1)
    v_r = -abs(np.random.weibull(2) * np.sqrt(2 * kb * temperature / mass))

    # Componentes de velocidad en coordenadas cartesianas
    v_x = v_r * np.sin(theta) * np.cos(phi) + v_theta * np.cos(theta) * np.cos(phi) - v_phi * np.sin(phi)
    v_y = v_r * np.sin(theta) * np.sin(phi) + v_theta * np.cos(theta) * np.sin(phi) + v_phi * np.cos(phi)
    v_z = v_r * np.cos(theta) - v_theta * np.sin(theta)

    return v_x, v_y, v_z

def velocidad_ion(temperature, mass):
    kb = 1.38064E-23  # Constante de Boltzmann en m^2 g s^-2 K^-1, kelvin, metros, segundos, kilogramos
    v = np.sqrt((2 * kb * temperature) / mass) * random.gauss(0, 1)
    return v

#Colision se detiene si átomo sale de segunda esfera de radio 2E-7
def event_condition(t, y, a, q, Omega, C4, C6, m_ion, m_a):
    # Definir condición de evento
    ionx, iony, ionz, ionvx, ionvy, ionvz, atomx, atomy, atomz, atomvx, atomvy, atomvz = y
    s = np.sqrt((atomx)**2 + (atomy)**2 + (atomz)**2)
    return s - 2.0E-6  #0.1E-6

# Indicar que el evento se debe buscar a través del cruce con cero
event_condition.terminal = True
event_condition.direction = 1

# Definición del vector de tiempo
t_span = (ti, tf)

# Resolución del sistema de ecuaciones diferenciales
def run_simulation(i):

    ionx_0=0.0
    iony_0=0.0
    ionz_0=0.0
    ionvx_0=velocidad_ion(T_ion, m_ion)
    ionvy_0=velocidad_ion(T_ion, m_ion)
    ionvz_0=velocidad_ion(T_ion, m_ion)
    atomx_0, atomy_0, atomz_0 = position_on_sphere(r0)
    atomvx_0, atomvy_0, atomvz_0 = velocidad_atom(T_atom, m_atom, atomx_0, atomy_0, atomz_0)
    y0 = [ionx_0, iony_0, ionz_0, ionvx_0, ionvy_0, ionvz_0, atomx_0, atomy_0, atomz_0, atomvx_0, atomvy_0, atomvz_0]

    results = []

    for collision in range (num_collisions):
          #inicialization variables
        solution = solve_ivp(system, t_span, y0, t_eval=np.linspace(t_span[0], t_span[1], dt), method='RK45', args=(a, q, Omega, C4, C6, m_ion, m_atom), rtol=ptol)

        # Extracción de las soluciones temporales
        t_sol = solution.t
        ionx_sol = solution.y[0]
        iony_sol = solution.y[1]
        ionz_sol = solution.y[2]
        ionvx_sol = solution.y[3]
        ionvy_sol = solution.y[4]
        ionvz_sol = solution.y[5]
        atomx_sol = solution.y[6]
        atomy_sol = solution.y[7]
        atomz_sol = solution.y[8]
        atomvx_sol = solution.y[9]
        atomvy_sol = solution.y[10]
        atomvz_sol = solution.y[11]

        salida_times = []

        for k, t in enumerate(t_sol):
            r = np.sqrt((atomx_sol[k] - ionx_sol[k])**2 + (atomy_sol[k] - iony_sol[k])**2 + (atomz_sol[k] - ionz_sol[k])**2)
            if r >= r0:
                salida_times.append(t)
                break  # Salir del bucle una vez que el átomo sale de la esfera

        #results.append([t_sol, ionx_sol, iony_sol, ionz_sol, ionvx_sol, ionvy_sol, ionvz_sol, atomx_sol, atomy_sol, atomz_sol, atomvx_sol, atomvy_sol, atomvz_sol])
        
        #Se actulizan las condiciones para el ion y el atomo
        atomx_0, atomy_0, atomz_0 = position_on_sphere(r0)
        atomvx_0, atomvy_0, atomvz_0 = velocidad_atom(T_atom, m_atom, atomx_0, atomy_0, atomz_0)
        y0 = [ionx_sol[-1], iony_sol[-1], ionz_sol[-1], ionvx_sol[-1], ionvy_sol[-1], ionvz_sol[-1], atomx_0, atomy_0, atomz_0, atomvx_0, atomvy_0, atomvz_0]

    return salida_times


if __name__ == '__main__':

    logging.info("Inicio de la ejecución")
    start_time = time.time()

    with Pool(processes=num_cpus) as pool:
        all_salida_times = pool.map(run_simulation, range(num_solution))
    #print(all_results)

    end_time = time.time()
    execution_time = (end_time - start_time)/60
    logging.info("Ejecución completada")
    print(f"Tiempo total de ejecución con 12 nucleos: {execution_time:.2f}minutos")
    #Ekin_total = []
    #for i, results in enumerate (all_results):   #cada colision en numero de trayectorias
        Ekin_colision = []
        for j, result in enumerate (results):     #parametros de cada colision
            t_sol=result[0]
            ionx_sol=result[1]
            iony_sol=result[2]
            ionz_sol=result[3]
            ionvx_sol=result[4]
            ionvy_sol=result[5]
            ionvz_sol=result[6]
            atomx_sol=result[7]
            atomy_sol=result[8]
            atomz_sol=result[9]
            atomvx_sol=result[10]
            atomvy_sol=result[11]
            atomvz_sol=result[12]

            E_kin = 0.5 * m_ion * (ionvx_sol**2 + ionvy_sol**2 + ionvz_sol**2)
            Tkin = np.mean(0.5 * m_ion * (ionvx_sol[1:]**2 + ionvy_sol[1:]**2 + ionvz_sol[1:]) * (t_sol[1:] - t_sol[:-1]) / (t_sol[-1] - t_sol[0]) * (len(t_sol) - 1)) * 1 / (3/2 * kB) * 1e6
            Ekin_colision.append(Tkin)
            t_mean = np.mean(t_sol)
            t_max = max(t_sol)  # Maximum value of the time array
            E_max = max(E_kin)  # Maximum value of the kinetic energy array
        Ekin_total.append(Ekin_colision)

    Ekin_total_promedio = np.mean(Ekin_total, axis=0)
    #plt.text(0.95, 0.95, '(a)', transform=plt.gca().transAxes, fontsize=16, verticalalignment='top', horizontalalignment='right')
    #print("Ekin_total_promedio", Ekin_total_promedio)

# Definir el rango máximo
#umbral_maximo = 20 # Ajusta este valor según tu necesidad

# Filtrar los datos por debajo del umbral máximo
#indices_validos = np.where(Ekin_total_promedio < umbral_maximo)
#Ekin_filtrado = np.array(Ekin_total_promedio)[indices_validos]
#num_collisiones_filtrado = np.arange(len(Ekin_total_promedio))[indices_validos]

# Graficar los datos filtrados
#plt.plot(num_collisiones_filtrado, Ekin_filtrado, label='Energía Cinética Promedio Filtrada')
#plt.title('Energía Cinética Promedio Filtrada por Número de Colisiones')
#plt.xlabel('Número de Colisiones')
#plt.ylabel('Energía Cinética Promedio (μK)')
#plt.grid()
#plt.legend()
#plt.show()
